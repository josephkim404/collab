# %% [markdown]
# Wordle is a game where a user has six guesses in order to correctly figure out the word of the day. Many players have optimized a stragety with a specific choice of words in order to reduce the amount of guesses that they do. With users figuring out strageties they may want to opt for a more challenging version of Wordle as they may get bored of the original version. Wordle Hard Mode is similar to regular Wordle however the difficulty jump may be attributed to the stipulation that every revealed clue must be used in the user's subsequent guesses. This means the user is boxed in and are required to be more creative with how they approach their gusses. However, this mode has mixed opinions as this stipulation would make it force players to guess the correct word while others rely on using differing words to narrow down their options. That is the question we'll try to figure out, whether Wordle Hardmode is actually harder than regular Wordle. To figure this out, we'll use reinforcement learning. Rienforcement learning is using an agnet to make decisions based on rewards and penalties. For Wordle, each guess will be used as the decision and the colors given back (gren, yellow, or grey) will be our reward and penalties. These reward and penalties will guide the agent's stragety for future guesses. By analyzing how the agent learns and improve its guessing stragety we can compare the agents and see which one truly poses a greater challenge for optimal gameplay.

# %%
import random
import numpy as np
import pandas as pd
import pickle
import os
from google.colab import drive

drive.mount('/content/drive')
# Initialize parameters
alpha = 0.3  # Learning rate
gamma = 0.9  # Discount factor
epsilon = 0.1  # Exploration rate
episodes = 10000  # Number of episodes

# Load word list from CSV
word_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/wordle.csv')  # Path to your CSV in Google Drive
word_list = word_data['word'].tolist()  # Convert the 'word' column to a list of words

# File path to save/load the Q-table
q_table_file = '/content/drive/My Drive/Colab Notebooks/q_table.pkl'

# Load the Q-table if it exists, otherwise initialize a new Q-table
if os.path.exists(q_table_file):
    with open(q_table_file, 'rb') as f:
        q_table = pickle.load(f)
    print("Loaded Q-table from file.")
else:
    q_table = {}  # Initialize an empty Q-table if no previous Q-table is found
    print("Initialized new Q-table.")
# Out:
# Mounted at /content/drive
# Initialized new Q-table.

# %% [markdown]
# We initialize a Q-table, which is a 2D array which shows the possible word choices and guesses. Two functions were made when it came to the reward and penalty section. A green letter would get a high positive reward indicating that the agent chose correctly then yellow for a smaller reward where the word was correct, but could do better for a higher reward. Then a grey for a penalty for the agent to not choose that word again.

# %%
# Define the reward mechanism for Wordle regular mode
def get_clue_easy(ans, guess):
    clue = ""
    for idx, letter in enumerate(guess):
        if letter == ans[idx]:
            clue += "G"
        elif letter in ans:
            clue += "Y"
        else:
            clue += "-"
    return clue

# %%
def get_clue_hard(ans, guess):
    clue = ""
    correct_positions = set()
    partial_correct_letters = set()

    for idx, letter in enumerate(guess):
        if letter == ans[idx]:
            clue += "G"
            correct_positions.add((idx, letter))
        elif letter in ans:
            clue += "Y"
            partial_correct_letters.add(letter)
        else:
            clue += "-"

    return clue, correct_positions, partial_correct_letters

# %%
# Reward function based on the clue
def reward_function(clue, guess, previous_guesses, answer):
    reward = 0
    for char in clue:
        if char == "G":
            reward += 10  # Positive reward for correct letters
        elif char == "Y":
            reward += 5  # Small reward for yellow letters
        else:
            reward -= 10  # Penalty for incorrect letters

    # Penalty for repeating the same guess
    if guess in previous_guesses:
        reward -= 10

    # Bonus for solving the Wordle
    if guess == answer:
        reward += 10

    return reward

# %% [markdown]
# To guide the agent's learning process, we implmeented an epsilon-greedy strategy. This balances exploration where the agent tries new guesses and exploitation where the agent uses their currently best guess to make a decision. The episolon value will be used for the agent's basis for how much it'll explore different possible stregeties. In addition to this exploration, the agent will exploit its current knowledge by referencing the highest Q-value which can possibly yield the best guess. This balance is important in order to balance as too much exploration means it may not be able to find the right answer at all and too much explotation

# %%
# Epsilon-greedy action selection for normal
def choose_action_easy(state, epsilon, q_table, word_list):
    if random.uniform(0, 1) < epsilon:
        # Exploration: Random guess
        choice = "Exploration"
        return random.choice(word_list), choice
    else:
        # Exploitation: Choose the best action based on Q-values
        if state not in q_table:
            q_table[state] = np.zeros(len(word_list))  # Initialize Q-values if state not present

        # Choose the action with the highest Q-value
        action_index = np.argmax(q_table[state])
        choice = "Exploitation"
        return word_list[action_index], choice

# %%
# Epsilon-greedy action selection for hard mode
def choose_action_hard(state, epsilon, q_table, word_list, correct_positions, partial_correct_letters):
    filtered_words = filter_word_list(word_list, correct_positions, partial_correct_letters)

    if not filtered_words:
        filtered_words = word_list  # Fallback to full list if no words match constraints
    if random.uniform(0, 1) < epsilon:
        # Exploration: Random guess
        choice = "Exploration"
        return random.choice(word_list), choice
    else:
        # Exploitation: Choose the best action based on Q-values
        if state not in q_table:
            q_table[state] = np.zeros(len(word_list))  # Initialize Q-values if state not present

        # Choose the action with the highest Q-value
        action_index = np.argmax(q_table[state])
        choice = "Exploitation"
        return word_list[action_index], choice

# %%
def update_q_table(state, action, reward, next_state, q_table, alpha, gamma, word_list):
    # Ensure the state and next state are in the Q-table
    if state not in q_table:
        q_table[state] = np.zeros(len(word_list))  # Initialize with zeros if state is not in Q-table
    if next_state not in q_table:
        q_table[next_state] = np.zeros(len(word_list))  # Initialize with zeros for next state

    action_index = word_list.index(action)  # Get the index of the action (word) in the word_list
    max_future_q = np.max(q_table[next_state])  # Get the maximum Q-value for the next state

    # Q-learning formula: Update the Q-value for the current state-action pair
    q_table[state][action_index] = q_table[state][action_index] + alpha * (
        reward + gamma * max_future_q - q_table[state][action_index]
    )

# %% [markdown]
# The training process involves running multiple events where the agent will attempt to guess the randomized word within the allowed attempts. In each event, the agent will use the epsilon-greedy strategy to either explore new guesses or exploit known strategies.
#
# After each guess, the agent receives feedback in the form of a clue and a corresponding reward, which is used to update the Q-table. The Q-table helps the agent refine its guesses by adjusting the values based on the rewards. The training continues for a set number of events, allowing the agent to learn and improve its strategy over time. The total rewards for each episode are tracked to monitor performance improvements.

# %%
def filter_word_list(word_list, correct_positions, partial_correct_letters):
    return [word for word in word_list
            if all(word[idx] == letter for idx, letter in correct_positions)
            and all(letter in word for letter in partial_correct_letters)]

# %%
# Track statistics
reward_count = []
epsilon_count = []
correct_count = []
wrong_count = 0
attempt = 0

# Training process for easy mode
for episode in range(episodes):
    answer = random.choice(word_list)  # Randomly choose a new answer for each episode
    state = "-----"  # Start with an empty clue state
    previous_guesses = []
    total_rewards = 0

    print(f'The answer for this episode is {answer}')

    for attempt in range(6):  # Up to 6 guesses per episode
        guess, strategy = choose_action_easy(state, epsilon, q_table, word_list)
        previous_guesses.append(guess)
        clue = get_clue_easy(answer, guess)
        reward = reward_function(clue, guess, previous_guesses, answer)

        print(f"Guess: {guess}, Clue: {clue}, Strategy: {strategy}, Attempt: {attempt + 1}")

        epsilon_count.append(strategy)  # Track exploration vs exploitation

        # Transition to the next state (the new clue)
        next_state = clue

        # Update Q-table
        update_q_table(state, guess, reward, next_state, q_table, alpha, gamma, word_list)

        # Update state and total rewards
        state = next_state
        total_rewards += reward

        # If the guess is correct, break out of the loop
        if guess == answer:
            print("Correct!")
            correct_count.append(1)
            break
    else:
        # If the episode ends without a correct guess, track it as wrong
        wrong_count += 1
        correct_count.append(0)

    reward_count.append(total_rewards)

# Output training results
print(f"Training completed after {episodes} episodes")
print(f"Correct guesses: {sum(correct_count)}, Wrong guesses: {wrong_count}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Guess: brill, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is caves
# Guess: ranke, Clue: -G--Y, Strategy: Exploration, Attempt: 1
# Guess: artsy, Clue: Y--Y-, Strategy: Exploitation, Attempt: 2
# Guess: calks, Clue: GG--G, Strategy: Exploitation, Attempt: 3
# Guess: abord, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: helot, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: goels, Clue: --Y-G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is dewan
# Guess: mauls, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: goers, Clue: --Y--, Strategy: Exploitation, Attempt: 2
# Guess: giros, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: melds, Clue: -G-Y-, Strategy: Exploitation, Attempt: 4
# Guess: argal, Clue: Y--G-, Strategy: Exploitation, Attempt: 5
# Guess: aruhe, Clue: Y---Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is glaze
# Guess: midge, Clue: ---YG, Strategy: Exploitation, Attempt: 1
# Guess: baize, Clue: -Y-GG, Strategy: Exploitation, Attempt: 2
# Guess: ackee, Clue: Y--YG, Strategy: Exploitation, Attempt: 3
# Guess: alias, Clue: YG-Y-, Strategy: Exploitation, Attempt: 4
# Guess: acute, Clue: Y---G, Strategy: Exploitation, Attempt: 5
# Guess: bebop, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is thane
# Guess: myope, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: fuses, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: heros, Clue: YY---, Strategy: Exploitation, Attempt: 3
# Guess: bidet, Clue: ---YY, Strategy: Exploration, Attempt: 4
# Guess: brief, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: herry, Clue: YY---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is soyas
# Guess: nidus, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: fusil, Clue: --Y--, Strategy: Exploitation, Attempt: 2
# Guess: girrs, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: fusks, Clue: --Y-G, Strategy: Exploitation, Attempt: 4
# Guess: bardo, Clue: -Y--Y, Strategy: Exploitation, Attempt: 5
# Guess: bauds, Clue: -Y--G, Strategy: Exploration, Attempt: 6
# The answer for this episode is exons
# Guess: quads, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: fussy, Clue: --YY-, Strategy: Exploitation, Attempt: 2
# Guess: brine, Clue: ---GY, Strategy: Exploitation, Attempt: 3
# Guess: anlas, Clue: -Y--G, Strategy: Exploitation, Attempt: 4
# Guess: minar, Clue: --Y--, Strategy: Exploration, Attempt: 5
# Guess: girsh, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is squab
# Guess: pitta, Clue: ----Y, Strategy: Exploration, Attempt: 1
# Guess: holes, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: holey, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: rater, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: goest, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: deeve, Clue: -----, Strategy: Exploration, Attempt: 6
# The answer for this episode is kelep
# Guess: rumpo, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: herse, Clue: -G--Y, Strategy: Exploitation, Attempt: 2
# Guess: aruhe, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: holks, Clue: --GY-, Strategy: Exploitation, Attempt: 4
# Guess: amuse, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: holla, Clue: --GY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is daurs
# Guess: stime, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: helps, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: fusts, Clue: -YY-G, Strategy: Exploitation, Attempt: 3
# Guess: ainga, Clue: Y---Y, Strategy: Exploitation, Attempt: 4
# Guess: brass, Clue: -YYYG, Strategy: Exploitation, Attempt: 5
# Guess: abuse, Clue: Y-GY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is icier
# Guess: temps, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: goety, Clue: --Y--, Strategy: Exploitation, Attempt: 2
# Guess: girth, Clue: -YY--, Strategy: Exploitation, Attempt: 3
# Guess: boofy, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: timon, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: gofer, Clue: ---GG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is owies
# Guess: parry, Clue: -----, Strategy: Exploration, Attempt: 1
# Guess: urine, Clue: --G-Y, Strategy: Exploitation, Attempt: 2
# Guess: alods, Clue: --Y-G, Strategy: Exploitation, Attempt: 3
# Guess: bards, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: fusty, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: girts, Clue: -Y--G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is lills
# Guess: wames, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: futon, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: yeard, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: yearn, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: goosy, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: hertz, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is boral
# Guess: roneo, Clue: YG--Y, Strategy: Exploitation, Attempt: 1
# Guess: acros, Clue: Y-GY-, Strategy: Exploitation, Attempt: 2
# Guess: afrit, Clue: Y-G--, Strategy: Exploitation, Attempt: 3
# Guess: anted, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: helve, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: gismo, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is brees
# Guess: seans, Clue: YY--G, Strategy: Exploitation, Attempt: 1
# Guess: agons, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: fuzee, Clue: ---GY, Strategy: Exploitation, Attempt: 3
# Guess: annal, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: neeze, Clue: -YG-Y, Strategy: Exploitation, Attempt: 5
# Guess: acidy, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is facts
# Guess: calla, Clue: YG--Y, Strategy: Exploitation, Attempt: 1
# Guess: acted, Clue: YYY--, Strategy: Exploitation, Attempt: 2
# Guess: amity, Clue: Y--G-, Strategy: Exploitation, Attempt: 3
# Guess: arums, Clue: Y---G, Strategy: Exploitation, Attempt: 4
# Guess: becap, Clue: --GY-, Strategy: Exploitation, Attempt: 5
# Guess: amyls, Clue: Y---G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is krubi
# Guess: arroz, Clue: -GY--, Strategy: Exploitation, Attempt: 1
# Guess: apers, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: herye, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: gisms, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: goffs, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: basho, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is istle
# Guess: briar, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: sewan, Clue: YY---, Strategy: Exploration, Attempt: 2
# Guess: biome, Clue: -Y--G, Strategy: Exploitation, Attempt: 3
# Guess: azoic, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: hesps, Clue: -YY-Y, Strategy: Exploitation, Attempt: 5
# Guess: edify, Clue: Y-Y--, Strategy: Exploration, Attempt: 6
# The answer for this episode is scoop
# Guess: deice, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: hests, Clue: --Y-Y, Strategy: Exploitation, Attempt: 2
# Guess: blaze, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: droke, Clue: --G--, Strategy: Exploitation, Attempt: 4
# Guess: borks, Clue: -Y--Y, Strategy: Exploitation, Attempt: 5
# Guess: bluid, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is laity
# Guess: dsobo, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: dying, Clue: -YG--, Strategy: Exploitation, Attempt: 2
# Guess: algum, Clue: YY---, Strategy: Exploitation, Attempt: 3
# Guess: biont, Clue: -Y--Y, Strategy: Exploitation, Attempt: 4
# Guess: blume, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: gogga, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is bossy
# Guess: enemy, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: fuzes, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: hollo, Clue: -G--Y, Strategy: Exploitation, Attempt: 3
# Guess: arums, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: holly, Clue: -G--G, Strategy: Exploitation, Attempt: 5
# Guess: apted, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is cyton
# Guess: bower, Clue: -Y---, Strategy: Exploration, Attempt: 1
# Guess: gogos, Clue: -Y-G-, Strategy: Exploitation, Attempt: 2
# Guess: ament, Clue: ---YY, Strategy: Exploitation, Attempt: 3
# Guess: brier, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: festy, Clue: ---YY, Strategy: Exploitation, Attempt: 5
# Guess: bries, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is suave
# Guess: flimp, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: flyer, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: hetes, Clue: -Y-YY, Strategy: Exploitation, Attempt: 3
# Guess: aloin, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: hemal, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 5
# Guess: bodle, Clue: ----G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is humic
# Guess: frabs, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: gesse, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: iotas, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: hemes, Clue: G-G--, Strategy: Exploitation, Attempt: 4
# Guess: advew, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: karoo, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is walds
# Guess: krone, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: ladle, Clue: YGYY-, Strategy: Exploitation, Attempt: 2
# Guess: abers, Clue: Y---G, Strategy: Exploitation, Attempt: 3
# Guess: becke, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: liart, Clue: Y-Y--, Strategy: Exploitation, Attempt: 5
# Guess: buddy, Clue: --YG-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is moste
# Guess: liger, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: heths, Clue: -YY-Y, Strategy: Exploitation, Attempt: 2
# Guess: amice, Clue: -Y--G, Strategy: Exploitation, Attempt: 3
# Guess: bacca, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: meffs, Clue: GY--Y, Strategy: Exploration, Attempt: 5
# Guess: acnes, Clue: ---YY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is rimer
# Guess: liman, Clue: -GG--, Strategy: Exploitation, Attempt: 1
# Guess: ajies, Clue: --YG-, Strategy: Exploitation, Attempt: 2
# Guess: apiol, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: gists, Clue: -G---, Strategy: Exploitation, Attempt: 4
# Guess: cooly, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: luger, Clue: ---GG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is orris
# Guess: mazed, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: menad, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: nutso, Clue: ---YY, Strategy: Exploitation, Attempt: 3
# Guess: brigs, Clue: -GY-G, Strategy: Exploitation, Attempt: 4
# Guess: adman, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: pareu, Clue: --G--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is bizzo
# Guess: pooja, Clue: -YY--, Strategy: Exploitation, Attempt: 1
# Guess: boogy, Clue: GYY--, Strategy: Exploitation, Attempt: 2
# Guess: addio, Clue: ---YG, Strategy: Exploitation, Attempt: 3
# Guess: bajan, Clue: G----, Strategy: Exploitation, Attempt: 4
# Guess: brims, Clue: G-Y--, Strategy: Exploitation, Attempt: 5
# Guess: appro, Clue: ----G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is epact
# Guess: rangy, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: goier, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: heuch, Clue: -Y-G-, Strategy: Exploitation, Attempt: 3
# Guess: crems, Clue: Y-Y--, Strategy: Exploration, Attempt: 4
# Guess: budge, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: holme, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is usual
# Guess: trend, Clue: -----, Strategy: Exploration, Attempt: 1
# Guess: shash, Clue: Y-YY-, Strategy: Exploitation, Attempt: 2
# Guess: arils, Clue: Y--YY, Strategy: Exploitation, Attempt: 3
# Guess: ariot, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: hemic, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: snowk, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is fluke
# Guess: soral, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: holms, Clue: --Y--, Strategy: Exploitation, Attempt: 2
# Guess: gitch, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: spire, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: fuzil, Clue: GY--Y, Strategy: Exploitation, Attempt: 5
# Guess: acock, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is husks
# Guess: smirs, Clue: Y---G, Strategy: Exploration, Attempt: 1
# Guess: ramin, Clue: -----, Strategy: Exploration, Attempt: 2
# Guess: swear, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: hemin, Clue: G----, Strategy: Exploitation, Attempt: 4
# Guess: brine, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: voema, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is spumy
# Guess: welkt, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: coifs, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: holon, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: creel, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: stims, Clue: G--GY, Strategy: Exploration, Attempt: 5
# Guess: abmho, Clue: --Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is gades
# Guess: creep, Clue: --YG-, Strategy: Exploitation, Attempt: 1
# Guess: apish, Clue: Y--Y-, Strategy: Exploitation, Attempt: 2
# Guess: calla, Clue: -G--Y, Strategy: Exploitation, Attempt: 3
# Guess: arval, Clue: Y--Y-, Strategy: Exploitation, Attempt: 4
# Guess: calls, Clue: -G--G, Strategy: Exploitation, Attempt: 5
# Guess: apter, Clue: Y--G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is yolks
# Guess: milds, Clue: --G-G, Strategy: Exploitation, Attempt: 1
# Guess: algum, Clue: -Y---, Strategy: Exploitation, Attempt: 2
# Guess: going, Clue: -G---, Strategy: Exploitation, Attempt: 3
# Guess: coomb, Clue: -GY--, Strategy: Exploitation, Attempt: 4
# Guess: apert, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: pheer, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is slubb
# Guess: pyran, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: tammy, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: chemo, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: doeks, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: holts, Clue: --Y-Y, Strategy: Exploitation, Attempt: 5
# Guess: bleak, Clue: YG---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is stupa
# Guess: haffs, Clue: -Y--Y, Strategy: Exploitation, Attempt: 1
# Guess: blunk, Clue: --G--, Strategy: Exploitation, Attempt: 2
# Guess: borms, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: homas, Clue: ---YY, Strategy: Exploitation, Attempt: 4
# Guess: briki, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: kelts, Clue: ---YY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is eskar
# Guess: meiny, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: gojis, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: homed, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: heugh, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: golds, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: homer, Clue: ---YG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is luaus
# Guess: poule, Clue: --YY-, Strategy: Exploration, Attempt: 1
# Guess: bring, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: mused, Clue: -GY--, Strategy: Exploitation, Attempt: 3
# Guess: apery, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: hemps, Clue: ----G, Strategy: Exploitation, Attempt: 5
# Guess: fuzzy, Clue: -G---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is fleek
# Guess: plats, Clue: -G---, Strategy: Exploitation, Attempt: 1
# Guess: cooms, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: ponds, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: profs, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: hevea, Clue: -Y-G-, Strategy: Exploitation, Attempt: 5
# Guess: amias, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is opahs
# Guess: tongs, Clue: -Y--G, Strategy: Exploration, Attempt: 1
# Guess: azole, Clue: Y-Y--, Strategy: Exploitation, Attempt: 2
# Guess: budis, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: fyces, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: fyked, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: value, Clue: -Y---, Strategy: Exploration, Attempt: 6
# The answer for this episode is woons
# Guess: qualm, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: romal, Clue: -G---, Strategy: Exploitation, Attempt: 2
# Guess: snare, Clue: YY---, Strategy: Exploration, Attempt: 3
# Guess: biota, Clue: --G--, Strategy: Exploitation, Attempt: 4
# Guess: borna, Clue: -G-G-, Strategy: Exploitation, Attempt: 5
# Guess: aider, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is dipso
# Guess: salop, Clue: Y--YY, Strategy: Exploitation, Attempt: 1
# Guess: arise, Clue: --YG-, Strategy: Exploitation, Attempt: 2
# Guess: apism, Clue: -YYG-, Strategy: Exploitation, Attempt: 3
# Guess: aesir, Clue: --YY-, Strategy: Exploitation, Attempt: 4
# Guess: cyano, Clue: ----G, Strategy: Exploration, Attempt: 5
# Guess: fykes, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is mease
# Guess: seirs, Clue: YG--Y, Strategy: Exploitation, Attempt: 1
# Guess: actin, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: hempy, Clue: -GY--, Strategy: Exploitation, Attempt: 3
# Guess: apgar, Clue: Y--Y-, Strategy: Exploitation, Attempt: 4
# Guess: calms, Clue: -Y-YY, Strategy: Exploitation, Attempt: 5
# Guess: alone, Clue: Y---G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is loave
# Guess: sonny, Clue: -G---, Strategy: Exploitation, Attempt: 1
# Guess: coomy, Clue: -GY--, Strategy: Exploitation, Attempt: 2
# Guess: aphid, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: hence, Clue: -Y--G, Strategy: Exploitation, Attempt: 4
# Guess: azons, Clue: Y-Y--, Strategy: Exploitation, Attempt: 5
# Guess: vakas, Clue: YY-Y-, Strategy: Exploration, Attempt: 6
# The answer for this episode is loche
# Guess: thaim, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: goldy, Clue: -GY--, Strategy: Exploitation, Attempt: 2
# Guess: aphis, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: gites, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: hewed, Clue: YY-Y-, Strategy: Exploitation, Attempt: 5
# Guess: almug, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is welsh
# Guess: tozed, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: hewer, Clue: YGYY-, Strategy: Exploitation, Attempt: 2
# Guess: abets, Clue: --Y-Y, Strategy: Exploitation, Attempt: 3
# Guess: blear, Clue: -YY--, Strategy: Exploitation, Attempt: 4
# Guess: boohs, Clue: ---YY, Strategy: Exploitation, Attempt: 5
# Guess: brill, Clue: ---YY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ghost
# Guess: tride, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: hench, Clue: Y---Y, Strategy: Exploitation, Attempt: 2
# Guess: brast, Clue: ---GG, Strategy: Exploitation, Attempt: 3
# Guess: arars, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: homes, Clue: YY--Y, Strategy: Exploitation, Attempt: 5
# Guess: ambit, Clue: ----G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is strak
# Guess: yojan, Clue: ---G-, Strategy: Exploitation, Attempt: 1
# Guess: cesti, Clue: --YY-, Strategy: Exploitation, Attempt: 2
# Guess: brink, Clue: -Y--G, Strategy: Exploitation, Attempt: 3
# Guess: azote, Clue: Y--Y-, Strategy: Exploitation, Attempt: 4
# Guess: calmy, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: golem, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is spuds
# Guess: saags, Clue: G---G, Strategy: Exploitation, Attempt: 1
# Guess: alfas, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: fyles, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: fyrds, Clue: ---GG, Strategy: Exploitation, Attempt: 4
# Guess: arbas, Clue: ----G, Strategy: Exploitation, Attempt: 5
# Guess: fytte, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is stedd
# Guess: goban, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: keyed, Clue: -Y-YG, Strategy: Exploitation, Attempt: 2
# Guess: aerie, Clue: -Y--Y, Strategy: Exploitation, Attempt: 3
# Guess: lotah, Clue: --Y--, Strategy: Exploration, Attempt: 4
# Guess: tatty, Clue: Y-YY-, Strategy: Exploration, Attempt: 5
# Guess: ariot, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is toran
# Guess: scams, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: giust, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: homey, Clue: -G---, Strategy: Exploitation, Attempt: 3
# Guess: coons, Clue: -GYY-, Strategy: Exploitation, Attempt: 4
# Guess: afoul, Clue: Y-Y--, Strategy: Exploitation, Attempt: 5
# Guess: budos, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is koori
# Guess: slops, Clue: --G--, Strategy: Exploitation, Attempt: 1
# Guess: borne, Clue: -GY--, Strategy: Exploitation, Attempt: 2
# Guess: apian, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: gived, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: goles, Clue: -G---, Strategy: Exploitation, Attempt: 5
# Guess: coops, Clue: -GG--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is salol
# Guess: solas, Clue: GYGYY, Strategy: Exploitation, Attempt: 1
# Guess: aalii, Clue: YGG--, Strategy: Exploitation, Attempt: 2
# Guess: abmho, Clue: Y---Y, Strategy: Exploitation, Attempt: 3
# Guess: brats, Clue: --Y-Y, Strategy: Exploitation, Attempt: 4
# Guess: bleat, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 5
# Guess: boeps, Clue: -Y--Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is dunks
# Guess: solas, Clue: Y---G, Strategy: Exploitation, Attempt: 1
# Guess: becks, Clue: ---GG, Strategy: Exploitation, Attempt: 2
# Guess: above, Clue: -----, Strategy: Exploration, Attempt: 3
# Guess: mossy, Clue: --YY-, Strategy: Exploitation, Attempt: 4
# Guess: brins, Clue: ---YG, Strategy: Exploitation, Attempt: 5
# Guess: bajra, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is route
# Guess: coate, Clue: -G-GG, Strategy: Exploitation, Attempt: 1
# Guess: acais, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: geste, Clue: -Y-GG, Strategy: Exploitation, Attempt: 3
# Guess: acker, Clue: ---YY, Strategy: Exploitation, Attempt: 4
# Guess: brims, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: golfs, Clue: -G---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is panda
# Guess: gyres, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: hayle, Clue: -G---, Strategy: Exploitation, Attempt: 2
# Guess: coopt, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: hewgh, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: gippy, Clue: --YY-, Strategy: Exploration, Attempt: 5
# Guess: briny, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is cepes
# Guess: lambs, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: gabba, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: laths, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: gabby, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: luter, Clue: ---G-, Strategy: Exploitation, Attempt: 5
# Guess: cetes, Clue: GG-GG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is pippy
# Guess: neifs, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: given, Clue: -G---, Strategy: Exploitation, Attempt: 2
# Guess: chide, Clue: --Y--, Strategy: Exploration, Attempt: 3
# Guess: giver, Clue: -G---, Strategy: Exploitation, Attempt: 4
# Guess: coost, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: palet, Clue: G----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ultra
# Guess: pieta, Clue: ---YG, Strategy: Exploitation, Attempt: 1
# Guess: bajri, Clue: -Y-G-, Strategy: Exploitation, Attempt: 2
# Guess: amice, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: hends, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: prigs, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: golly, Clue: --YY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is coils
# Guess: roles, Clue: -GY-G, Strategy: Exploitation, Attempt: 1
# Guess: herds, Clue: ----G, Strategy: Exploration, Attempt: 2
# Guess: gable, Clue: ---G-, Strategy: Exploitation, Attempt: 3
# Guess: cetyl, Clue: G---Y, Strategy: Exploitation, Attempt: 4
# Guess: amias, Clue: --G-G, Strategy: Exploitation, Attempt: 5
# Guess: tough, Clue: -G---, Strategy: Exploration, Attempt: 6
# The answer for this episode is swell
# Guess: sargo, Clue: G----, Strategy: Exploitation, Attempt: 1
# Guess: bring, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: tears, Clue: -Y--Y, Strategy: Exploitation, Attempt: 3
# Guess: blunt, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: golpe, Clue: --Y-Y, Strategy: Exploitation, Attempt: 5
# Guess: blebs, Clue: -YG-Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is flown
# Guess: umpie, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: vitae, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: water, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: henge, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: gives, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: yelks, Clue: --Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is emirs
# Guess: slabs, Clue: Y---G, Strategy: Exploitation, Attempt: 1
# Guess: bedad, Clue: -Y---, Strategy: Exploitation, Attempt: 2
# Guess: golps, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: gades, Clue: ---YG, Strategy: Exploitation, Attempt: 4
# Guess: bajus, Clue: ----G, Strategy: Exploitation, Attempt: 5
# Guess: gadge, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is reffo
# Guess: agile, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: homie, Clue: -Y--Y, Strategy: Exploitation, Attempt: 2
# Guess: lubes, Clue: ---Y-, Strategy: Exploration, Attempt: 3
# Guess: hexed, Clue: -G-Y-, Strategy: Exploitation, Attempt: 4
# Guess: argan, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: gombo, Clue: -Y--G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is looie
# Guess: archi, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: homos, Clue: -G-Y-, Strategy: Exploitation, Attempt: 2
# Guess: argil, Clue: ---GY, Strategy: Exploitation, Attempt: 3
# Guess: annas, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: beats, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: gomer, Clue: -G-Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is gybes
# Guess: binal, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: henna, Clue: -Y---, Strategy: Exploitation, Attempt: 2
# Guess: gompa, Clue: G----, Strategy: Exploitation, Attempt: 3
# Guess: brink, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: henny, Clue: -Y--Y, Strategy: Exploitation, Attempt: 5
# Guess: blurb, Clue: Y---Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is poney
# Guess: board, Clue: -G---, Strategy: Exploitation, Attempt: 1
# Guess: coots, Clue: -GY--, Strategy: Exploitation, Attempt: 2
# Guess: howls, Clue: -G---, Strategy: Exploration, Attempt: 3
# Guess: cooze, Clue: -GY-Y, Strategy: Exploitation, Attempt: 4
# Guess: vetch, Clue: -Y---, Strategy: Exploration, Attempt: 5
# Guess: gonad, Clue: -GG--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is kiddy
# Guess: pouff, Clue: -----, Strategy: Exploration, Attempt: 1
# Guess: buffo, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: champ, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: clews, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: cloys, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: hexer, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is jehus
# Guess: clubs, Clue: --Y-G, Strategy: Exploitation, Attempt: 1
# Guess: bardy, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: crews, Clue: --Y-G, Strategy: Exploitation, Attempt: 3
# Guess: haute, Clue: Y-Y-Y, Strategy: Exploration, Attempt: 4
# Guess: arvos, Clue: ----G, Strategy: Exploitation, Attempt: 5
# Guess: gadid, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is pixie
# Guess: crisp, Clue: --Y-Y, Strategy: Exploitation, Attempt: 1
# Guess: blech, Clue: --Y--, Strategy: Exploitation, Attempt: 2
# Guess: gizmo, Clue: -G---, Strategy: Exploitation, Attempt: 3
# Guess: copal, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: glace, Clue: ----G, Strategy: Exploitation, Attempt: 5
# Guess: gadis, Clue: ---G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is veles
# Guess: cruve, Clue: ---YY, Strategy: Exploitation, Attempt: 1
# Guess: brine, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: honan, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: darks, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: gadjo, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: elsin, Clue: YYY--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is cloud
# Guess: evohe, Clue: --G--, Strategy: Exploitation, Attempt: 1
# Guess: tuple, Clue: -Y-Y-, Strategy: Exploration, Attempt: 2
# Guess: boets, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: gonch, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 4
# Guess: boeuf, Clue: -Y-G-, Strategy: Exploitation, Attempt: 5
# Guess: amici, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is immew
# Guess: fleys, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: glade, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: honda, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: agami, Clue: ---YY, Strategy: Exploration, Attempt: 4
# Guess: bring, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: glads, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is simba
# Guess: flour, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: gears, Clue: --Y-Y, Strategy: Exploitation, Attempt: 2
# Guess: bleed, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: hents, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: honds, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: berms, Clue: Y--YY, Strategy: Exploration, Attempt: 6
# The answer for this episode is heads
# Guess: gnows, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: gadso, Clue: -YYY-, Strategy: Exploitation, Attempt: 2
# Guess: furry, Clue: -----, Strategy: Exploration, Attempt: 3
# Guess: haiku, Clue: GY---, Strategy: Exploitation, Attempt: 4
# Guess: aloes, Clue: Y--YG, Strategy: Exploitation, Attempt: 5
# Guess: alibi, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is lobar
# Guess: homas, Clue: -G-G-, Strategy: Exploitation, Attempt: 1
# Guess: aides, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: hepar, Clue: ---GG, Strategy: Exploitation, Attempt: 3
# Guess: arbor, Clue: YYGYG, Strategy: Exploitation, Attempt: 4
# Guess: aalii, Clue: YYY--, Strategy: Exploitation, Attempt: 5
# Guess: amlas, Clue: Y-YG-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is bends
# Guess: hynde, Clue: --GGY, Strategy: Exploitation, Attempt: 1
# Guess: abear, Clue: -YY--, Strategy: Exploitation, Attempt: 2
# Guess: books, Clue: G---G, Strategy: Exploitation, Attempt: 3
# Guess: algae, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: honed, Clue: --GYY, Strategy: Exploitation, Attempt: 5
# Guess: acned, Clue: --GYY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is cumin
# Guess: lairy, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: glaik, Clue: ---G-, Strategy: Exploitation, Attempt: 2
# Guess: cezve, Clue: G----, Strategy: Exploitation, Attempt: 3
# Guess: motey, Clue: Y----, Strategy: Exploration, Attempt: 4
# Guess: herbs, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: corbe, Clue: G----, Strategy: Exploration, Attempt: 6
# The answer for this episode is ursid
# Guess: liane, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: gonef, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: liker, Clue: -Y--Y, Strategy: Exploitation, Attempt: 3
# Guess: narre, Clue: --YY-, Strategy: Exploration, Attempt: 4
# Guess: brios, Clue: -GY-Y, Strategy: Exploitation, Attempt: 5
# Guess: adore, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ileus
# Guess: lotas, Clue: Y---G, Strategy: Exploitation, Attempt: 1
# Guess: bedel, Clue: -Y-YY, Strategy: Exploitation, Attempt: 2
# Guess: along, Clue: -G---, Strategy: Exploitation, Attempt: 3
# Guess: copay, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: means, Clue: -Y--G, Strategy: Exploitation, Attempt: 5
# Guess: azoth, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is messy
# Guess: mobby, Clue: G---G, Strategy: Exploitation, Attempt: 1
# Guess: algal, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: monal, Clue: G----, Strategy: Exploitation, Attempt: 3
# Guess: brins, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: honer, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: hexyl, Clue: -G-Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is jumby
# Guess: odist, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: ombre, Clue: -YY--, Strategy: Exploitation, Attempt: 2
# Guess: booky, Clue: Y---G, Strategy: Exploitation, Attempt: 3
# Guess: goest, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: oobit, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: glair, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is foxed
# Guess: plies, Clue: ---G-, Strategy: Exploitation, Attempt: 1
# Guess: chace, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: trabs, Clue: -----, Strategy: Exploration, Attempt: 3
# Guess: plotz, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: glams, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: plume, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is glaze
# Guess: powan, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: turbo, Clue: -----, Strategy: Exploration, Attempt: 2
# Guess: pratt, Clue: --G--, Strategy: Exploitation, Attempt: 3
# Guess: boron, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: saice, Clue: -Y--G, Strategy: Exploitation, Attempt: 5
# Guess: azuki, Clue: YY---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is usher
# Guess: sapor, Clue: Y---G, Strategy: Exploitation, Attempt: 1
# Guess: bedes, Clue: -Y-GY, Strategy: Exploitation, Attempt: 2
# Guess: addax, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: rouen, Clue: Y-YG-, Strategy: Exploration, Attempt: 4
# Guess: adzed, Clue: ---G-, Strategy: Exploitation, Attempt: 5
# Guess: chack, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is roums
# Guess: serac, Clue: Y-Y--, Strategy: Exploitation, Attempt: 1
# Guess: buffa, Clue: -Y---, Strategy: Exploitation, Attempt: 2
# Guess: goner, Clue: -G--Y, Strategy: Exploitation, Attempt: 3
# Guess: arvee, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: gongs, Clue: -G--G, Strategy: Exploitation, Attempt: 5
# Guess: aptly, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is sagos
# Guess: spayd, Clue: G-Y--, Strategy: Exploitation, Attempt: 1
# Guess: appui, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: herby, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: spiff, Clue: G----, Strategy: Exploitation, Attempt: 4
# Guess: briny, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: stern, Clue: G----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is apeak
# Guess: sicko, Clue: ---Y-, Strategy: Exploration, Attempt: 1
# Guess: heyed, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 2
# Guess: boffo, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: tardy, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: gonia, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: hones, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is grody
# Guess: tofts, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: gonif, Clue: GY---, Strategy: Exploitation, Attempt: 2
# Guess: coyer, Clue: -YY-Y, Strategy: Exploration, Attempt: 3
# Guess: nerds, Clue: --YG-, Strategy: Exploration, Attempt: 4
# Guess: apnea, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: yauds, Clue: Y--G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is drams
# Guess: sacra, Clue: YY-YY, Strategy: Exploration, Attempt: 1
# Guess: adeem, Clue: YY--Y, Strategy: Exploitation, Attempt: 2
# Guess: amble, Clue: YY---, Strategy: Exploitation, Attempt: 3
# Guess: fulls, Clue: ----G, Strategy: Exploration, Attempt: 4
# Guess: gaffe, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: gonks, Clue: ----G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is akela
# Guess: spasm, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: gland, Clue: -YY--, Strategy: Exploitation, Attempt: 2
# Guess: bools, Clue: ---G-, Strategy: Exploitation, Attempt: 3
# Guess: dexie, Clue: -Y--Y, Strategy: Exploration, Attempt: 4
# Guess: blurs, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: bleak, Clue: -YGYY, Strategy: Exploration, Attempt: 6
# The answer for this episode is ummed
# Guess: rebel, Clue: -Y-G-, Strategy: Exploitation, Attempt: 1
# Guess: amide, Clue: -G-YY, Strategy: Exploitation, Attempt: 2
# Guess: aegis, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: wrath, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: sloes, Clue: ---G-, Strategy: Exploitation, Attempt: 5
# Guess: chaco, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is curia
# Guess: wilga, Clue: -Y--G, Strategy: Exploitation, Attempt: 1
# Guess: azure, Clue: Y-YY-, Strategy: Exploitation, Attempt: 2
# Guess: arise, Clue: YYY--, Strategy: Exploitation, Attempt: 3
# Guess: spyre, Clue: ---Y-, Strategy: Exploration, Attempt: 4
# Guess: yeeds, Clue: -----, Strategy: Exploration, Attempt: 5
# Guess: wacks, Clue: -YY--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is suits
# Guess: tepee, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: herds, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: gaffs, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: gaged, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: ducal, Clue: -G---, Strategy: Exploitation, Attempt: 5
# Guess: coped, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is humic
# Guess: alapa, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: cerci, Clue: Y--YY, Strategy: Exploitation, Attempt: 2
# Guess: arish, Clue: --Y-Y, Strategy: Exploitation, Attempt: 3
# Guess: bleep, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: fouer, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: deoxy, Clue: -----, Strategy: Exploration, Attempt: 6
# The answer for this episode is dawns
# Guess: mines, Clue: --Y-G, Strategy: Exploitation, Attempt: 1
# Guess: equid, Clue: ----Y, Strategy: Exploration, Attempt: 2
# Guess: honey, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: glans, Clue: --YGG, Strategy: Exploitation, Attempt: 4
# Guess: acted, Clue: Y---Y, Strategy: Exploitation, Attempt: 5
# Guess: brava, Clue: --Y-Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is bleak
# Guess: orach, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: glare, Clue: -GY-Y, Strategy: Exploitation, Attempt: 2
# Guess: kines, Clue: Y--Y-, Strategy: Exploration, Attempt: 3
# Guess: faked, Clue: -YYY-, Strategy: Exploration, Attempt: 4
# Guess: anear, Clue: Y-GG-, Strategy: Exploitation, Attempt: 5
# Guess: abuna, Clue: YY--Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is chant
# Guess: pingo, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: glary, Clue: --G--, Strategy: Exploitation, Attempt: 2
# Guess: borts, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: hiant, Clue: Y-GGG, Strategy: Exploitation, Attempt: 4
# Guess: abask, Clue: Y-G--, Strategy: Exploitation, Attempt: 5
# Guess: antes, Clue: YYY--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is abmho
# Guess: scone, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: glass, Clue: --Y--, Strategy: Exploitation, Attempt: 2
# Guess: glaum, Clue: --Y-Y, Strategy: Exploitation, Attempt: 3
# Guess: blees, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: goety, Clue: -Y---, Strategy: Exploration, Attempt: 5
# Guess: gonna, Clue: -Y--Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is koros
# Guess: tapen, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: uraos, Clue: -Y-GG, Strategy: Exploitation, Attempt: 2
# Guess: acmes, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: gager, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: hongi, Clue: -G---, Strategy: Exploitation, Attempt: 5
# Guess: copen, Clue: -G---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is cuing
# Guess: vaute, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: glaur, Clue: Y--Y-, Strategy: Exploitation, Attempt: 2
# Guess: calos, Clue: G----, Strategy: Exploitation, Attempt: 3
# Guess: ramis, Clue: ---Y-, Strategy: Exploration, Attempt: 4
# Guess: hicks, Clue: -YY--, Strategy: Exploitation, Attempt: 5
# Guess: booms, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is cooee
# Guess: yarns, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: paska, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: mites, Clue: ---G-, Strategy: Exploitation, Attempt: 3
# Guess: chado, Clue: G---Y, Strategy: Exploitation, Attempt: 4
# Guess: amice, Clue: ---YG, Strategy: Exploitation, Attempt: 5
# Guess: itchy, Clue: --Y--, Strategy: Exploration, Attempt: 6
# The answer for this episode is gored
# Guess: pelts, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: gonof, Clue: GG-Y-, Strategy: Exploitation, Attempt: 2
# Guess: abysm, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: aglee, Clue: -Y-GY, Strategy: Exploitation, Attempt: 4
# Guess: added, Clue: -YYGG, Strategy: Exploitation, Attempt: 5
# Guess: abers, Clue: --YY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is mulch
# Guess: anoas, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: appui, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: hided, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: heres, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: herls, Clue: Y--Y-, Strategy: Exploitation, Attempt: 5
# Guess: calpa, Clue: Y-G--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is fakie
# Guess: crame, Clue: --Y-G, Strategy: Exploitation, Attempt: 1
# Guess: mythi, Clue: ----Y, Strategy: Exploration, Attempt: 2
# Guess: honks, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: hider, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 4
# Guess: boffs, Clue: --YY-, Strategy: Exploitation, Attempt: 5
# Guess: brise, Clue: --Y-G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is resus
# Guess: daily, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: dolly, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: drill, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: gonys, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: koffs, Clue: ----G, Strategy: Exploration, Attempt: 5
# Guess: gages, Clue: ---YG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is senti
# Guess: dusts, Clue: --YGY, Strategy: Exploitation, Attempt: 1
# Guess: acted, Clue: --YY-, Strategy: Exploitation, Attempt: 2
# Guess: sield, Clue: GYY--, Strategy: Exploration, Attempt: 3
# Guess: addle, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: honky, Clue: --G--, Strategy: Exploitation, Attempt: 5
# Guess: borty, Clue: ---G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is maist
# Guess: easts, Clue: -GYYY, Strategy: Exploitation, Attempt: 1
# Guess: aboil, Clue: Y--Y-, Strategy: Exploitation, Attempt: 2
# Guess: calps, Clue: -G--Y, Strategy: Exploitation, Attempt: 3
# Guess: arvos, Clue: Y---Y, Strategy: Exploitation, Attempt: 4
# Guess: brave, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: glazy, Clue: --Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is prods
# Guess: filmy, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: washy, Clue: --Y--, Strategy: Exploration, Attempt: 2
# Guess: gleam, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: roped, Clue: YYY-Y, Strategy: Exploration, Attempt: 4
# Guess: adits, Clue: -Y--G, Strategy: Exploitation, Attempt: 5
# Guess: azurn, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is arvee
# Guess: fisks, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: fists, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: gleba, Clue: --Y-Y, Strategy: Exploitation, Attempt: 3
# Guess: blend, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: glean, Clue: --YY-, Strategy: Exploitation, Attempt: 5
# Guess: brisk, Clue: -G---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is hoves
# Guess: goods, Clue: -GY-G, Strategy: Exploitation, Attempt: 1
# Guess: admen, Clue: ---G-, Strategy: Exploitation, Attempt: 2
# Guess: chads, Clue: -Y--G, Strategy: Exploitation, Attempt: 3
# Guess: seils, Clue: YY--G, Strategy: Exploration, Attempt: 4
# Guess: agony, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: glebe, Clue: --Y-Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is salet
# Guess: grame, Clue: --Y-Y, Strategy: Exploitation, Attempt: 1
# Guess: blent, Clue: -YY-G, Strategy: Exploitation, Attempt: 2
# Guess: aioli, Clue: Y--Y-, Strategy: Exploitation, Attempt: 3
# Guess: calve, Clue: -GG-Y, Strategy: Exploitation, Attempt: 4
# Guess: above, Clue: Y---Y, Strategy: Exploitation, Attempt: 5
# Guess: bravo, Clue: --Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is scoot
# Guess: hider, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: hooka, Clue: -YG--, Strategy: Exploitation, Attempt: 2
# Guess: wexes, Clue: ----Y, Strategy: Exploration, Attempt: 3
# Guess: honor, Clue: -Y-G-, Strategy: Exploitation, Attempt: 4
# Guess: amido, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: hooch, Clue: -YGY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is bezil
# Guess: hushy, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: iglus, Clue: Y-Y--, Strategy: Exploitation, Attempt: 2
# Guess: buffe, Clue: G---Y, Strategy: Exploitation, Attempt: 3
# Guess: amici, Clue: --Y-Y, Strategy: Exploitation, Attempt: 4
# Guess: blert, Clue: GYY--, Strategy: Exploitation, Attempt: 5
# Guess: adeem, Clue: --YY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is deair
# Guess: illth, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: herma, Clue: -GY-Y, Strategy: Exploitation, Attempt: 2
# Guess: adorn, Clue: YY-Y-, Strategy: Exploitation, Attempt: 3
# Guess: alods, Clue: Y--Y-, Strategy: Exploitation, Attempt: 4
# Guess: calyx, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: gonzo, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is rorts
# Guess: isnae, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: murls, Clue: --G-G, Strategy: Exploration, Attempt: 2
# Guess: alias, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: gaids, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: gaily, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: kagos, Clue: ---YG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is doric
# Guess: kiaat, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# ...
# Guess: ickle, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: wifed, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: wiper, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: wired, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is pubis
# Guess: biddy, Clue: YY---, Strategy: Exploration, Attempt: 1
# Guess: bizes, Clue: YY--G, Strategy: Exploitation, Attempt: 2
# Guess: agree, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: sells, Clue: Y---G, Strategy: Exploration, Attempt: 4
# Guess: begar, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: honer, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is azyme
# Guess: withy, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: icons, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: wormy, Clue: ---GY, Strategy: Exploitation, Attempt: 3
# Guess: anole, Clue: G---G, Strategy: Exploitation, Attempt: 4
# Guess: alike, Clue: G---G, Strategy: Exploitation, Attempt: 5
# Guess: aline, Clue: G---G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ruddy
# Guess: worth, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: pilow, Clue: -----, Strategy: Exploration, Attempt: 2
# Guess: wreak, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: grrls, Clue: -YY--, Strategy: Exploitation, Attempt: 4
# Guess: borts, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: whirl, Clue: ---Y-, Strategy: Exploration, Attempt: 6
# The answer for this episode is tenny
# Guess: wreck, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: gothy, Clue: --Y-G, Strategy: Exploitation, Attempt: 2
# Guess: bassi, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: wudus, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: wurst, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: ictal, Clue: --Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is bilks
# Guess: wynds, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: wasps, Clue: --Y-G, Strategy: Exploration, Attempt: 2
# Guess: basso, Clue: G-YY-, Strategy: Exploitation, Attempt: 3
# Guess: tranq, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: wyted, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: yacka, Clue: ---G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is norma
# Guess: ycond, Clue: --YY-, Strategy: Exploitation, Attempt: 1
# Guess: buaze, Clue: --Y--, Strategy: Exploitation, Attempt: 2
# Guess: gotta, Clue: -G--G, Strategy: Exploitation, Attempt: 3
# Guess: ardri, Clue: YY-Y-, Strategy: Exploitation, Attempt: 4
# Guess: aloud, Clue: Y-Y--, Strategy: Exploitation, Attempt: 5
# Guess: bundh, Clue: --Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is glees
# Guess: yechy, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: grrrl, Clue: G---Y, Strategy: Exploitation, Attempt: 2
# Guess: amity, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: yield, Clue: --GY-, Strategy: Exploitation, Attempt: 4
# Guess: angel, Clue: --YGY, Strategy: Exploitation, Attempt: 5
# Guess: acute, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is octal
# Guess: yogin, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: grubs, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: yoofs, Clue: -YY--, Strategy: Exploitation, Attempt: 3
# Guess: borty, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 4
# Guess: bonce, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 5
# Guess: bonds, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is sizes
# Guess: yucko, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: yugas, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: geans, Clue: -Y--G, Strategy: Exploitation, Attempt: 3
# Guess: bacon, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: zaidy, Clue: Y-Y--, Strategy: Exploitation, Attempt: 5
# Guess: bunds, Clue: ----G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is pokey
# Guess: zante, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: ictic, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: zesty, Clue: -Y--G, Strategy: Exploitation, Attempt: 3
# Guess: baddy, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: geare, Clue: -Y--Y, Strategy: Exploitation, Attempt: 5
# Guess: bogus, Clue: -G---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is keyed
# Guess: zineb, Clue: ---G-, Strategy: Exploitation, Attempt: 1
# Guess: chevy, Clue: --Y-Y, Strategy: Exploitation, Attempt: 2
# Guess: blowy, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: ictus, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: zippy, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: idant, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is casco
# Guess: ziram, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: hoors, Clue: -YY-Y, Strategy: Exploitation, Attempt: 2
# Guess: bedim, Clue: -----, Strategy: Exploration, Attempt: 3
# Guess: zoons, Clue: -YY-Y, Strategy: Exploitation, Attempt: 4
# Guess: arefy, Clue: Y----, Strategy: Exploration, Attempt: 5
# Guess: hones, Clue: -Y--Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is mincy
# Guess: zouks, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: zupas, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: lycee, Clue: -YY--, Strategy: Exploitation, Attempt: 3
# Guess: hunks, Clue: --G--, Strategy: Exploration, Attempt: 4
# Guess: bower, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: spelk, Clue: -----, Strategy: Exploration, Attempt: 6
# The answer for this episode is soral
# Guess: gumma, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: ideal, Clue: ---GG, Strategy: Exploitation, Attempt: 2
# Guess: arear, Clue: YY-GY, Strategy: Exploitation, Attempt: 3
# Guess: abide, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: honey, Clue: -G---, Strategy: Exploitation, Attempt: 5
# Guess: sokah, Clue: GG-G-, Strategy: Exploration, Attempt: 6
# The answer for this episode is punch
# Guess: hooly, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: hongi, Clue: Y-G--, Strategy: Exploitation, Attempt: 2
# Guess: aorta, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: syces, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: gouch, Clue: --YGG, Strategy: Exploitation, Attempt: 5
# Guess: acyls, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is naras
# Guess: arsey, Clue: YYY--, Strategy: Exploitation, Attempt: 1
# Guess: amnic, Clue: Y-Y--, Strategy: Exploitation, Attempt: 2
# Guess: tanty, Clue: -GY--, Strategy: Exploration, Attempt: 3
# Guess: apses, Clue: Y-Y-G, Strategy: Exploitation, Attempt: 4
# Guess: along, Clue: Y--Y-, Strategy: Exploitation, Attempt: 5
# Guess: caple, Clue: -G---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is dater
# Guess: uhuru, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: hoosh, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: rawer, Clue: YG-GG, Strategy: Exploitation, Attempt: 3
# Guess: aband, Clue: Y-Y-Y, Strategy: Exploitation, Attempt: 4
# Guess: dovie, Clue: G---Y, Strategy: Exploration, Attempt: 5
# Guess: amlas, Clue: Y--Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is qibla
# Guess: rawer, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: faddy, Clue: -Y---, Strategy: Exploration, Attempt: 2
# Guess: grued, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: fangs, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: gruel, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: ideas, Clue: Y--Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is recap
# Guess: jammy, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: grues, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 2
# Guess: boned, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: giust, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: sames, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 5
# Guess: boner, Clue: ---YY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is unlit
# Guess: shaws, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: tawai, Clue: Y---Y, Strategy: Exploitation, Attempt: 2
# Guess: brios, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: akees, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: abaci, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: idees, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ouped
# Guess: braza, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: buteo, Clue: -G-GY, Strategy: Exploitation, Attempt: 2
# Guess: abort, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: gouge, Clue: -YY-Y, Strategy: Exploitation, Attempt: 4
# Guess: amine, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: ident, Clue: -YY--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is apods
# Guess: panes, Clue: YY--G, Strategy: Exploitation, Attempt: 1
# Guess: agria, Clue: G---Y, Strategy: Exploitation, Attempt: 2
# Guess: amman, Clue: G--Y-, Strategy: Exploitation, Attempt: 3
# Guess: argal, Clue: G--Y-, Strategy: Exploitation, Attempt: 4
# Guess: argan, Clue: G--Y-, Strategy: Exploitation, Attempt: 5
# Guess: argil, Clue: G----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is gular
# Guess: expel, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: idiom, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: slime, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: grufe, Clue: GYY--, Strategy: Exploitation, Attempt: 4
# Guess: adios, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: hongs, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is terne
# Guess: booby, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: nonas, Clue: Y-Y--, Strategy: Exploitation, Attempt: 2
# Guess: bundt, Clue: --Y-Y, Strategy: Exploitation, Attempt: 3
# Guess: blubs, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: fixer, Clue: ---YY, Strategy: Exploitation, Attempt: 5
# Guess: yawls, Clue: -----, Strategy: Exploration, Attempt: 6
# The answer for this episode is mossy
# Guess: corms, Clue: -G-YY, Strategy: Exploitation, Attempt: 1
# Guess: aesir, Clue: --G--, Strategy: Exploitation, Attempt: 2
# Guess: bowes, Clue: -G--Y, Strategy: Exploitation, Attempt: 3
# Guess: asper, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: gruff, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: babes, Clue: ----Y, Strategy: Exploration, Attempt: 6
# The answer for this episode is amias
# Guess: purge, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: gases, Clue: -YY-G, Strategy: Exploitation, Attempt: 2
# Guess: aitus, Clue: GY--G, Strategy: Exploitation, Attempt: 3
# Guess: aboon, Clue: G----, Strategy: Exploitation, Attempt: 4
# Guess: bubbe, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: vleis, Clue: ---YG, Strategy: Exploration, Attempt: 6
# The answer for this episode is tendu
# Guess: fests, Clue: -G-Y-, Strategy: Exploitation, Attempt: 1
# Guess: armet, Clue: ---YY, Strategy: Exploitation, Attempt: 2
# Guess: brute, Clue: --YYY, Strategy: Exploitation, Attempt: 3
# Guess: amman, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: idiot, Clue: -Y--Y, Strategy: Exploitation, Attempt: 5
# Guess: bohea, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is chape
# Guess: fitts, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: herma, Clue: YY--Y, Strategy: Exploitation, Attempt: 2
# Guess: swaly, Clue: --G--, Strategy: Exploration, Attempt: 3
# Guess: bowet, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: hooty, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: honks, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is kibei
# Guess: rifer, Clue: -G-G-, Strategy: Exploitation, Attempt: 1
# Guess: aight, Clue: -G---, Strategy: Exploitation, Attempt: 2
# Guess: cowks, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: fetal, Clue: -Y---, Strategy: Exploration, Attempt: 4
# Guess: grume, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: idled, Clue: Y--G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is tacan
# Guess: whats, Clue: --YY-, Strategy: Exploitation, Attempt: 1
# Guess: bubal, Clue: ---G-, Strategy: Exploitation, Attempt: 2
# Guess: chewy, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: honor, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: gouks, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: delos, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is yarto
# Guess: emyds, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: goura, Clue: -Y-YY, Strategy: Exploitation, Attempt: 2
# Guess: alvar, Clue: Y--YY, Strategy: Exploitation, Attempt: 3
# Guess: aroid, Clue: YYY--, Strategy: Exploitation, Attempt: 4
# Guess: amnio, Clue: Y---G, Strategy: Exploitation, Attempt: 5
# Guess: begat, Clue: ---YY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is wield
# Guess: faiks, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: gourd, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: gears, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: grump, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: ranas, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: axman, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is dwaal
# Guess: barbs, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: grund, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: idler, Clue: -YY--, Strategy: Exploitation, Attempt: 3
# Guess: bortz, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: barfs, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: grunt, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is hules
# Guess: basts, Clue: --Y-G, Strategy: Exploitation, Attempt: 1
# Guess: bassy, Clue: --YY-, Strategy: Exploitation, Attempt: 2
# Guess: bubas, Clue: -G--G, Strategy: Exploitation, Attempt: 3
# Guess: aread, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: penal, Clue: -Y--Y, Strategy: Exploration, Attempt: 5
# Guess: bohos, Clue: --Y-G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is moten
# Guess: bayle, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: buffi, Clue: -----, Strategy: Exploration, Attempt: 2
# Guess: biach, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: blite, Clue: ---YY, Strategy: Exploitation, Attempt: 4
# Guess: bruts, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: hoove, Clue: -GY-Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is mawed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-8daa315d9557> in <cell line: 9>()
#      16
#      17     for attempt in range(6):  # Up to 6 guesses per episode
# ---> 18         guess, strategy = choose_action_easy(state, epsilon, q_table, word_list)
#      19         previous_guesses.append(guess)
#      20         clue = get_clue_easy(answer, guess)
#
# <ipython-input-26-96554e5ce93a> in choose_action_easy(state, epsilon, q_table, word_list)
#      11
#      12         # Choose the action with the highest Q-value
# ---> 13         action_index = np.argmax(q_table[state])
#      14         choice = "Exploitation"
#      15         return word_list[action_index], choice
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in argmax(a, axis, out, keepdims)
#    1227     """
#    1228     kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1229     return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#    1230
#    1231
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      57
#      58     try:
# ---> 59         return bound(*args, **kwds)
#      60     except TypeError:
#      61         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %%
# Track statistics for hard mode
reward_count = []
epsilon_count = []
correct_count = []
wrong_count = 0
attempt = 0


# Training process for hard mode
for episode in range(episodes):
    answer = random.choice(word_list)  # Randomly choose a new answer for each episode
    state = "-----"  # Start with an empty clue state
    previous_guesses = []
    correct_positions = set()
    partial_correct_letters = set()
    total_rewards = 0

    print(f'The answer for this episode is {answer}')

    for attempt in range(6):  # Up to 6 guesses per episode
        guess, strategy = choose_action_hard(state, epsilon, q_table, word_list, correct_positions, partial_correct_letters)
        clue, new_correct_positions, new_partial_correct_letters = get_clue_hard(answer, guess)
        reward = reward_function(clue, guess, previous_guesses, answer)
        print(f"Guess: {guess}, Clue: {clue}, Strategy: {strategy}, Attempt: {attempt + 1}")

        epsilon_count.append(strategy)  # Track exploration vs exploitation

        # Transition to the next state (the new clue)
        next_state = clue

        # Update Q-table
        update_q_table(state, guess, reward, next_state, q_table, alpha, gamma, word_list)

        # Update state and total rewards
        state = next_state
        total_rewards += reward
       # Update constraints
        correct_positions.update(new_correct_positions)
        partial_correct_letters.update(new_partial_correct_letters)
        # If the guess is correct, break out of the loop
        if guess == answer:
            print("Correct!")
            correct_count.append(1)
            break
    else:
        # If the episode ends without a correct guess, track it as wrong
        wrong_count += 1
        correct_count.append(0)

    reward_count.append(total_rewards)

# Output training results
print(f"Training completed after {episodes} episodes")
print(f"Correct guesses: {sum(correct_count)}, Wrong guesses: {wrong_count}")
# Out:
# Streaming output truncated to the last 5000 lines.
# The answer for this episode is yapok
# Guess: skers, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: bumfs, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: skets, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: bumph, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: clows, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: butyl, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is scope
# Guess: skews, Clue: G-Y-Y, Strategy: Exploitation, Attempt: 1
# Guess: abune, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: byway, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: skews, Clue: G-Y-Y, Strategy: Exploitation, Attempt: 4
# Guess: abuse, Clue: ---YG, Strategy: Exploitation, Attempt: 5
# Guess: alone, Clue: --G-G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is apeek
# Guess: skews, Clue: -YG--, Strategy: Exploitation, Attempt: 1
# Guess: odium, Clue: -----, Strategy: Exploration, Attempt: 2
# Guess: skier, Clue: -Y-G-, Strategy: Exploitation, Attempt: 3
# Guess: aghas, Clue: G--Y-, Strategy: Exploitation, Attempt: 4
# Guess: aeons, Clue: GY---, Strategy: Exploitation, Attempt: 5
# Guess: adays, Clue: G-Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is scorn
# Guess: skran, Clue: G-Y-G, Strategy: Exploitation, Attempt: 1
# Guess: abies, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: potoo, Clue: -Y-YY, Strategy: Exploration, Attempt: 3
# Guess: admit, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: skran, Clue: G-Y-G, Strategy: Exploitation, Attempt: 5
# Guess: jamon, Clue: ---YG, Strategy: Exploration, Attempt: 6
# The answer for this episode is pinup
# Guess: skran, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: clats, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: slade, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: slain, Clue: ---YY, Strategy: Exploitation, Attempt: 4
# Guess: goety, Clue: -----, Strategy: Exploration, Attempt: 5
# Guess: slaps, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is gaily
# Guess: slash, Clue: -YY--, Strategy: Exploitation, Attempt: 1
# Guess: anoas, Clue: Y--Y-, Strategy: Exploitation, Attempt: 2
# Guess: aygre, Clue: YYY--, Strategy: Exploitation, Attempt: 3
# Guess: agami, Clue: YYY-Y, Strategy: Exploitation, Attempt: 4
# Guess: ablow, Clue: Y-Y--, Strategy: Exploitation, Attempt: 5
# Guess: aways, Clue: Y-YY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is realm
# Guess: slate, Clue: -YG-Y, Strategy: Exploitation, Attempt: 1
# Guess: geyer, Clue: -G-YY, Strategy: Exploration, Attempt: 2
# Guess: abune, Clue: Y---Y, Strategy: Exploitation, Attempt: 3
# Guess: armed, Clue: YYYY-, Strategy: Exploitation, Attempt: 4
# Guess: abrin, Clue: Y-Y--, Strategy: Exploitation, Attempt: 5
# Guess: awdls, Clue: Y--G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is molla
# Guess: slate, Clue: -YY--, Strategy: Exploitation, Attempt: 1
# Guess: anode, Clue: Y-Y--, Strategy: Exploitation, Attempt: 2
# Guess: aweel, Clue: Y---Y, Strategy: Exploitation, Attempt: 3
# Guess: armed, Clue: Y-Y--, Strategy: Exploitation, Attempt: 4
# Guess: aweto, Clue: Y---Y, Strategy: Exploitation, Attempt: 5
# Guess: armer, Clue: Y-Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is tegua
# Guess: albas, Clue: Y--Y-, Strategy: Exploration, Attempt: 1
# Guess: selfs, Clue: -G---, Strategy: Exploration, Attempt: 2
# Guess: badly, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: bumps, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: bumpy, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: zincs, Clue: -----, Strategy: Exploration, Attempt: 6
# The answer for this episode is akees
# Guess: slept, Clue: Y-G--, Strategy: Exploitation, Attempt: 1
# Guess: agmas, Clue: G--YG, Strategy: Exploitation, Attempt: 2
# Guess: abear, Clue: G-GY-, Strategy: Exploitation, Attempt: 3
# Guess: abbas, Clue: G--YG, Strategy: Exploitation, Attempt: 4
# Guess: abear, Clue: G-GY-, Strategy: Exploitation, Attempt: 5
# Guess: abbas, Clue: G--YG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is cures
# Guess: slipe, Clue: Y---Y, Strategy: Exploitation, Attempt: 1
# Guess: armet, Clue: -Y-G-, Strategy: Exploitation, Attempt: 2
# Guess: agila, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: jasps, Clue: --Y-G, Strategy: Exploration, Attempt: 4
# Guess: allow, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: slogs, Clue: Y---G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is elate
# Guess: sloid, Clue: -G---, Strategy: Exploitation, Attempt: 1
# Guess: baels, Clue: -YYY-, Strategy: Exploitation, Attempt: 2
# Guess: afore, Clue: Y---G, Strategy: Exploitation, Attempt: 3
# Guess: dress, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: buxom, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: sluts, Clue: -G-G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is viffs
# Guess: smear, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: coats, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: caaed, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: smirr, Clue: Y-Y--, Strategy: Exploitation, Attempt: 4
# Guess: awful, Clue: --G--, Strategy: Exploitation, Attempt: 5
# Guess: argle, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is abamp
# Guess: wharf, Clue: --G--, Strategy: Exploration, Attempt: 1
# Guess: argol, Clue: G----, Strategy: Exploitation, Attempt: 2
# Guess: apgar, Clue: GY-Y-, Strategy: Exploitation, Attempt: 3
# Guess: abcee, Clue: GG---, Strategy: Exploitation, Attempt: 4
# Guess: abyss, Clue: GG---, Strategy: Exploitation, Attempt: 5
# Guess: jaded, Clue: -Y---, Strategy: Exploration, Attempt: 6
# The answer for this episode is updry
# Guess: smite, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: smits, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: lysis, Clue: -Y---, Strategy: Exploration, Attempt: 3
# Guess: bunas, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: bunce, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: bunch, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is areas
# Guess: smock, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: arras, Clue: GGYGG, Strategy: Exploration, Attempt: 2
# Guess: aahed, Clue: GY-Y-, Strategy: Exploitation, Attempt: 3
# Guess: abeam, Clue: G-GG-, Strategy: Exploitation, Attempt: 4
# Guess: aargh, Clue: GYY--, Strategy: Exploitation, Attempt: 5
# Guess: abbey, Clue: G--Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is flume
# Guess: smoke, Clue: -Y--G, Strategy: Exploitation, Attempt: 1
# Guess: butts, Clue: -Y---, Strategy: Exploration, Attempt: 2
# Guess: bunco, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: bunde, Clue: -Y--G, Strategy: Exploitation, Attempt: 4
# Guess: alkie, Clue: -G--G, Strategy: Exploitation, Attempt: 5
# Guess: agami, Clue: ---G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is dunny
# Guess: smush, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: buyer, Clue: -GY--, Strategy: Exploitation, Attempt: 2
# Guess: afire, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: snabs, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: lands, Clue: --GY-, Strategy: Exploration, Attempt: 5
# Guess: aecia, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is imari
# Guess: snary, Clue: --GG-, Strategy: Exploitation, Attempt: 1
# Guess: aceta, Clue: Y---Y, Strategy: Exploitation, Attempt: 2
# Guess: armil, Clue: YYYY-, Strategy: Exploitation, Attempt: 3
# Guess: abris, Clue: Y-YY-, Strategy: Exploitation, Attempt: 4
# Guess: alans, Clue: Y-G--, Strategy: Exploitation, Attempt: 5
# Guess: agmas, Clue: Y-YY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is smack
# Guess: scoug, Clue: GY---, Strategy: Exploration, Attempt: 1
# Guess: adbot, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: arras, Clue: Y--YY, Strategy: Exploitation, Attempt: 3
# Guess: ailed, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: arras, Clue: Y--YY, Strategy: Exploitation, Attempt: 5
# Guess: aimed, Clue: Y-Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is rejig
# Guess: sneap, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: buzzy, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: snell, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: keyed, Clue: -G-Y-, Strategy: Exploration, Attempt: 4
# Guess: after, Clue: ---YY, Strategy: Exploitation, Attempt: 5
# Guess: atria, Clue: --YG-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is malic
# Guess: bolar, Clue: --GY-, Strategy: Exploration, Attempt: 1
# Guess: mzees, Clue: G----, Strategy: Exploration, Attempt: 2
# Guess: apgar, Clue: Y--Y-, Strategy: Exploitation, Attempt: 3
# Guess: junks, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: soave, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: bwana, Clue: --Y-Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is oxids
# Guess: sober, Clue: YY---, Strategy: Exploitation, Attempt: 1
# Guess: anglo, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: claut, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: sodic, Clue: YYYY-, Strategy: Exploitation, Attempt: 4
# Guess: absey, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: bwazi, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ratha
# Guess: sodic, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: solah, Clue: ---YY, Strategy: Exploitation, Attempt: 2
# Guess: atrip, Clue: YYY--, Strategy: Exploitation, Attempt: 3
# Guess: agami, Clue: Y-Y--, Strategy: Exploitation, Attempt: 4
# Guess: awing, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: arras, Clue: YYYY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is logie
# Guess: soles, Clue: -GYY-, Strategy: Exploitation, Attempt: 1
# Guess: acerb, Clue: --Y--, Strategy: Exploitation, Attempt: 2
# Guess: byded, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: cloye, Clue: -YY-G, Strategy: Exploitation, Attempt: 4
# Guess: acock, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: bydes, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is dimly
# Guess: soles, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: stuff, Clue: -----, Strategy: Exploration, Attempt: 2
# Guess: solid, Clue: --YYY, Strategy: Exploitation, Attempt: 3
# Guess: agent, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: solid, Clue: --YYY, Strategy: Exploitation, Attempt: 5
# Guess: agers, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is quern
# Guess: solid, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: solus, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: cloye, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: clave, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: clavi, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: sonde, Clue: --Y-Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is sound
# Guess: soths, Clue: GG--Y, Strategy: Exploitation, Attempt: 1
# Guess: abate, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: soths, Clue: GG--Y, Strategy: Exploitation, Attempt: 3
# Guess: abaya, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: soths, Clue: GG--Y, Strategy: Exploitation, Attempt: 5
# Guess: abbas, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is volae
# Guess: soths, Clue: -G---, Strategy: Exploitation, Attempt: 1
# Guess: baffs, Clue: -Y---, Strategy: Exploitation, Attempt: 2
# Guess: bundh, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: sowse, Clue: -G--G, Strategy: Exploitation, Attempt: 4
# Guess: agape, Clue: Y-Y-G, Strategy: Exploitation, Attempt: 5
# Guess: afars, Clue: Y-Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is zeins
# Guess: spacy, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: arras, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: atoll, Clue: -----, Strategy: Exploration, Attempt: 3
# Guess: spait, Clue: Y--Y-, Strategy: Exploitation, Attempt: 4
# Guess: ayins, Clue: --GGG, Strategy: Exploitation, Attempt: 5
# Guess: abele, Clue: --Y-Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is folks
# Guess: spake, Clue: Y--G-, Strategy: Exploitation, Attempt: 1
# Guess: albas, Clue: -Y--G, Strategy: Exploitation, Attempt: 2
# Guess: alkos, Clue: -YYYG, Strategy: Exploitation, Attempt: 3
# Guess: abele, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: cloys, Clue: -YY-G, Strategy: Exploitation, Attempt: 5
# Guess: acold, Clue: --YY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is meted
# Guess: spald, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: cabal, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: spans, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: spaws, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: spean, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: byked, Clue: ---GG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is gurry
# Guess: spile, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: spina, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: spire, Clue: ---G-, Strategy: Exploitation, Attempt: 3
# Guess: babus, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: cloys, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: cloze, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is pongs
# Guess: spoke, Clue: YYY--, Strategy: Exploitation, Attempt: 1
# Guess: agape, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 2
# Guess: angry, Clue: -YY--, Strategy: Exploitation, Attempt: 3
# Guess: anole, Clue: -YY--, Strategy: Exploitation, Attempt: 4
# Guess: anomy, Clue: -YY--, Strategy: Exploitation, Attempt: 5
# Guess: ansae, Clue: -YY--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is moove
# Guess: spoke, Clue: --G-G, Strategy: Exploitation, Attempt: 1
# Guess: adapt, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: spore, Clue: --G-G, Strategy: Exploitation, Attempt: 3
# Guess: adaws, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: sprat, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: sprug, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is these
# Guess: maids, Clue: ----Y, Strategy: Exploration, Attempt: 1
# Guess: claws, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: clays, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: clean, Clue: --G--, Strategy: Exploitation, Attempt: 4
# Guess: argon, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: spurs, Clue: Y---Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is swans
# Guess: sputa, Clue: G---Y, Strategy: Exploitation, Attempt: 1
# Guess: adzed, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: coopt, Clue: -----, Strategy: Exploration, Attempt: 3
# Guess: spyre, Clue: G----, Strategy: Exploitation, Attempt: 4
# Guess: aphid, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: cobbs, Clue: ----G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is deans
# Guess: squab, Clue: Y--Y-, Strategy: Exploitation, Attempt: 1
# Guess: ayins, Clue: Y--GG, Strategy: Exploitation, Attempt: 2
# Guess: aceta, Clue: Y-Y-Y, Strategy: Exploitation, Attempt: 3
# Guess: amber, Clue: Y--Y-, Strategy: Exploitation, Attempt: 4
# Guess: ayins, Clue: Y--GG, Strategy: Exploitation, Attempt: 5
# Guess: achar, Clue: Y--Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is teals
# Guess: staig, Clue: YYG--, Strategy: Exploitation, Attempt: 1
# Guess: abbes, Clue: Y--YG, Strategy: Exploitation, Attempt: 2
# Guess: largo, Clue: YY---, Strategy: Exploration, Attempt: 3
# Guess: angry, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: cobby, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: staig, Clue: YYG--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is finos
# Guess: staig, Clue: Y--Y-, Strategy: Exploitation, Attempt: 1
# Guess: ayins, Clue: --YYG, Strategy: Exploitation, Attempt: 2
# Guess: etuis, Clue: ---YG, Strategy: Exploration, Attempt: 3
# Guess: along, Clue: --YY-, Strategy: Exploitation, Attempt: 4
# Guess: arret, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: stain, Clue: Y--YY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is curli
# Guess: stain, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: clubs, Clue: GYY--, Strategy: Exploitation, Attempt: 2
# Guess: abbot, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: stang, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: stash, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: stats, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is spial
# Guess: steam, Clue: G--G-, Strategy: Exploitation, Attempt: 1
# Guess: abode, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: cobia, Clue: ---YY, Strategy: Exploitation, Attempt: 3
# Guess: attap, Clue: Y--GY, Strategy: Exploitation, Attempt: 4
# Guess: abuzz, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: coble, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is nubia
# Guess: stear, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: zizit, Clue: -Y-G-, Strategy: Exploration, Attempt: 2
# Guess: agile, Clue: Y-Y--, Strategy: Exploitation, Attempt: 3
# Guess: awmry, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: cobra, Clue: --G-G, Strategy: Exploitation, Attempt: 5
# Guess: adays, Clue: Y-Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is yarto
# Guess: stede, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: bunds, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: stile, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: bundt, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: clear, Clue: ---YY, Strategy: Exploitation, Attempt: 5
# Guess: attap, Clue: YYYY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ludic
# Guess: still, Clue: --YYY, Strategy: Exploitation, Attempt: 1
# Guess: hared, Clue: ----Y, Strategy: Exploration, Attempt: 2
# Guess: cleat, Clue: YY---, Strategy: Exploitation, Attempt: 3
# Guess: angst, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: still, Clue: --YYY, Strategy: Exploitation, Attempt: 5
# Guess: agger, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is dahls
# Guess: still, Clue: Y--GY, Strategy: Exploitation, Attempt: 1
# Guess: abyes, Clue: Y---G, Strategy: Exploitation, Attempt: 2
# Guess: aloos, Clue: YY--G, Strategy: Exploitation, Attempt: 3
# Guess: acari, Clue: Y-Y--, Strategy: Exploitation, Attempt: 4
# Guess: lobes, Clue: Y---G, Strategy: Exploration, Attempt: 5
# Guess: aloos, Clue: YY--G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is wynns
# Guess: still, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: cobza, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: sting, Clue: Y--G-, Strategy: Exploitation, Attempt: 3
# Guess: albee, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: stink, Clue: Y--G-, Strategy: Exploitation, Attempt: 5
# Guess: dicer, Clue: -----, Strategy: Exploration, Attempt: 6
# The answer for this episode is immew
# Guess: stoic, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: snick, Clue: --Y--, Strategy: Exploration, Attempt: 2
# Guess: loral, Clue: -----, Strategy: Exploration, Attempt: 3
# Guess: stole, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: cleck, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: bykes, Clue: ---G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is apode
# Guess: stoma, Clue: --G-Y, Strategy: Exploitation, Attempt: 1
# Guess: adzes, Clue: GY-Y-, Strategy: Exploitation, Attempt: 2
# Guess: abeam, Clue: G-YY-, Strategy: Exploitation, Attempt: 3
# Guess: abers, Clue: G-Y--, Strategy: Exploitation, Attempt: 4
# Guess: adyta, Clue: GY--Y, Strategy: Exploitation, Attempt: 5
# Guess: abets, Clue: G-Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is fiars
# Guess: storm, Clue: Y--G-, Strategy: Exploitation, Attempt: 1
# Guess: album, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: cocas, Clue: ---YG, Strategy: Exploitation, Attempt: 3
# Guess: aloof, Clue: Y---Y, Strategy: Exploitation, Attempt: 4
# Guess: armil, Clue: YY-Y-, Strategy: Exploitation, Attempt: 5
# Guess: aduki, Clue: Y---Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is kissy
# Guess: stout, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: cocci, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: cleek, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: cleep, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: bocks, Clue: ---YY, Strategy: Exploration, Attempt: 5
# Guess: attap, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is shaps
# Guess: stove, Clue: G----, Strategy: Exploitation, Attempt: 1
# Guess: aphis, Clue: YYY-G, Strategy: Exploitation, Attempt: 2
# Guess: narco, Clue: -Y---, Strategy: Exploration, Attempt: 3
# Guess: bundu, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: strep, Clue: G---Y, Strategy: Exploitation, Attempt: 5
# Guess: adzes, Clue: Y---G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is brere
# Guess: taras, Clue: --Y--, Strategy: Exploration, Attempt: 1
# Guess: bylaw, Clue: G----, Strategy: Exploitation, Attempt: 2
# Guess: aphis, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: strew, Clue: --YY-, Strategy: Exploitation, Attempt: 4
# Guess: ranid, Clue: Y----, Strategy: Exploration, Attempt: 5
# Guess: cocco, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is snipy
# Guess: gadid, Clue: ---Y-, Strategy: Exploration, Attempt: 1
# Guess: clubs, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: clefs, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: cleft, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: stria, Clue: G--Y-, Strategy: Exploitation, Attempt: 5
# Guess: aerie, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is kirns
# Guess: strim, Clue: Y-GY-, Strategy: Exploitation, Attempt: 1
# Guess: keech, Clue: G----, Strategy: Exploration, Attempt: 2
# Guess: apian, Clue: --Y-Y, Strategy: Exploitation, Attempt: 3
# Guess: apoop, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: usual, Clue: -Y---, Strategy: Exploration, Attempt: 5
# Guess: bundy, Clue: --Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is bunia
# Guess: strim, Clue: ---G-, Strategy: Exploitation, Attempt: 1
# Guess: bacca, Clue: GY--G, Strategy: Exploitation, Attempt: 2
# Guess: abacs, Clue: YYY--, Strategy: Exploitation, Attempt: 3
# Guess: agars, Clue: Y-Y--, Strategy: Exploitation, Attempt: 4
# Guess: awned, Clue: Y-G--, Strategy: Exploitation, Attempt: 5
# Guess: agoge, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is puris
# Guess: stumm, Clue: Y-Y--, Strategy: Exploitation, Attempt: 1
# Guess: awner, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: clegs, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: cabas, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: cabby, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: style, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is cants
# Guess: suete, Clue: Y--G-, Strategy: Exploitation, Attempt: 1
# Guess: alcid, Clue: Y-Y--, Strategy: Exploitation, Attempt: 2
# Guess: ampul, Clue: Y----, Strategy: Exploration, Attempt: 3
# Guess: hoody, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: sugan, Clue: Y--YY, Strategy: Exploitation, Attempt: 5
# Guess: aimer, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ought
# Guess: sugan, Clue: -GG--, Strategy: Exploitation, Attempt: 1
# Guess: gyves, Clue: Y----, Strategy: Exploration, Attempt: 2
# Guess: cocks, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: bungs, Clue: -G-Y-, Strategy: Exploitation, Attempt: 4
# Guess: again, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: bungy, Clue: -G-Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is bolas
# Guess: suids, Clue: Y---G, Strategy: Exploitation, Attempt: 1
# Guess: aloos, Clue: YYYYG, Strategy: Exploitation, Attempt: 2
# Guess: clave, Clue: -YY--, Strategy: Exploration, Attempt: 3
# Guess: antae, Clue: Y--G-, Strategy: Exploitation, Attempt: 4
# Guess: hyens, Clue: ----G, Strategy: Exploration, Attempt: 5
# Guess: caber, Clue: -YY--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is swoon
# Guess: suite, Clue: G----, Strategy: Exploitation, Attempt: 1
# Guess: aping, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: cluck, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: sural, Clue: G----, Strategy: Exploitation, Attempt: 4
# Guess: apiol, Clue: ---G-, Strategy: Exploitation, Attempt: 5
# Guess: bacca, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is curly
# Guess: swami, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: swamp, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: swamy, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: cabin, Clue: G----, Strategy: Exploitation, Attempt: 4
# Guess: apish, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: swapt, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is weird
# Guess: sweet, Clue: -YYY-, Strategy: Exploitation, Attempt: 1
# Guess: afoul, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: sweet, Clue: -YYY-, Strategy: Exploitation, Attempt: 3
# Guess: afrit, Clue: --YY-, Strategy: Exploitation, Attempt: 4
# Guess: arris, Clue: -YYY-, Strategy: Exploitation, Attempt: 5
# Guess: afros, Clue: --Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is slake
# Guess: sweet, Clue: G-YY-, Strategy: Exploitation, Attempt: 1
# Guess: abers, Clue: Y-Y-Y, Strategy: Exploitation, Attempt: 2
# Guess: porty, Clue: -----, Strategy: Exploration, Attempt: 3
# Guess: sweet, Clue: G-YY-, Strategy: Exploitation, Attempt: 4
# Guess: abets, Clue: Y-Y-Y, Strategy: Exploitation, Attempt: 5
# Guess: ambit, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is arsis
# Guess: sweet, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: cocky, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: mummy, Clue: -----, Strategy: Exploration, Attempt: 3
# Guess: swive, Clue: Y-Y--, Strategy: Exploitation, Attempt: 4
# Guess: awoke, Clue: G----, Strategy: Exploitation, Attempt: 5
# Guess: apism, Clue: G-YY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is flump
# Guess: sybil, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: feist, Clue: G----, Strategy: Exploration, Attempt: 2
# Guess: apism, Clue: -Y--Y, Strategy: Exploitation, Attempt: 3
# Guess: apert, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: bunia, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: bunje, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is agist
# Guess: syens, Clue: Y---Y, Strategy: Exploitation, Attempt: 1
# Guess: armil, Clue: G--Y-, Strategy: Exploitation, Attempt: 2
# Guess: froes, Clue: ----Y, Strategy: Exploration, Attempt: 3
# Guess: cleik, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: clued, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: symar, Clue: Y--Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is mases
# Guess: synch, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: cocoa, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: clems, Clue: --YYG, Strategy: Exploitation, Attempt: 3
# Guess: acros, Clue: Y---G, Strategy: Exploitation, Attempt: 4
# Guess: slung, Clue: Y----, Strategy: Exploration, Attempt: 5
# Guess: cocos, Clue: ----G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is arret
# Guess: sythe, Clue: --Y-Y, Strategy: Exploitation, Attempt: 1
# Guess: aport, Clue: G--YG, Strategy: Exploitation, Attempt: 2
# Guess: abear, Clue: G-YYY, Strategy: Exploitation, Attempt: 3
# Guess: abask, Clue: G-Y--, Strategy: Exploitation, Attempt: 4
# Guess: adyta, Clue: G--YY, Strategy: Exploitation, Attempt: 5
# Guess: abies, Clue: G--G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is avian
# Guess: syver, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: byres, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: tabby, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: bunjy, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: byrls, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: ragus, Clue: -Y---, Strategy: Exploration, Attempt: 6
# The answer for this episode is afara
# Guess: tachs, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: sandy, Clue: -Y---, Strategy: Exploration, Attempt: 2
# Guess: bunko, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: taels, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: bunks, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: tains, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is white
# Guess: taish, Clue: Y-G-Y, Strategy: Exploitation, Attempt: 1
# Guess: acidy, Clue: --G--, Strategy: Exploitation, Attempt: 2
# Guess: argot, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: clems, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: byssi, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: clepe, Clue: --Y-G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is facet
# Guess: taish, Clue: YG---, Strategy: Exploitation, Attempt: 1
# Guess: aggry, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: codas, Clue: Y--Y-, Strategy: Exploitation, Attempt: 3
# Guess: ayins, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: codec, Clue: Y--GY, Strategy: Exploitation, Attempt: 5
# Guess: abysm, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is aleck
# Guess: takis, Clue: -YY--, Strategy: Exploitation, Attempt: 1
# Guess: antar, Clue: G--Y-, Strategy: Exploitation, Attempt: 2
# Guess: aeros, Clue: GY---, Strategy: Exploitation, Attempt: 3
# Guess: addax, Clue: G--Y-, Strategy: Exploitation, Attempt: 4
# Guess: aesir, Clue: GY---, Strategy: Exploitation, Attempt: 5
# Guess: added, Clue: G--Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is dorrs
# Guess: taler, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: clept, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: taste, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: bytes, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: cable, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: tasty, Clue: --Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is plouk
# Guess: tater, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: taupe, Clue: --YY-, Strategy: Exploitation, Attempt: 2
# Guess: arrow, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: clues, Clue: -GY--, Strategy: Exploitation, Attempt: 4
# Guess: aflaj, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: byway, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is lamer
# Guess: tawse, Clue: -G--Y, Strategy: Exploitation, Attempt: 1
# Guess: aglee, Clue: Y-YGY, Strategy: Exploitation, Attempt: 2
# Guess: abbot, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: codec, Clue: ---G-, Strategy: Exploitation, Attempt: 4
# Guess: bacco, Clue: -G---, Strategy: Exploitation, Attempt: 5
# Guess: baffy, Clue: -G---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is masty
# Guess: tayra, Clue: YGY-Y, Strategy: Exploitation, Attempt: 1
# Guess: aback, Clue: Y-Y--, Strategy: Exploitation, Attempt: 2
# Guess: awols, Clue: Y---Y, Strategy: Exploitation, Attempt: 3
# Guess: armor, Clue: Y-Y--, Strategy: Exploitation, Attempt: 4
# Guess: awork, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: coded, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is peels
# Guess: tayra, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: tazza, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: teats, Clue: -G--G, Strategy: Exploitation, Attempt: 3
# Guess: agape, Clue: ---YY, Strategy: Exploitation, Attempt: 4
# Guess: attar, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: teels, Clue: -GGGG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ammon
# Guess: teels, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: teend, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: cluey, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: teens, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: clump, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: clung, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is dojos
# Guess: teffs, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: cabob, Clue: ---G-, Strategy: Exploitation, Attempt: 2
# Guess: baccy, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: teggs, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: caboc, Clue: ---G-, Strategy: Exploitation, Attempt: 5
# Guess: bacha, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is gents
# Guess: temse, Clue: YG-YY, Strategy: Exploitation, Attempt: 1
# Guess: abaft, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: clerk, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: caaed, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: clunk, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: clype, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is amine
# Guess: coths, Clue: -----, Strategy: Exploration, Attempt: 1
# Guess: temse, Clue: -YY-G, Strategy: Exploitation, Attempt: 2
# Guess: acorn, Clue: G---Y, Strategy: Exploitation, Attempt: 3
# Guess: aecia, Clue: GY-YY, Strategy: Exploitation, Attempt: 4
# Guess: aalii, Clue: GY-YY, Strategy: Exploitation, Attempt: 5
# Guess: aalii, Clue: GY-YY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is reata
# Guess: temse, Clue: YG--Y, Strategy: Exploitation, Attempt: 1
# Guess: goner, Clue: ---YY, Strategy: Exploration, Attempt: 2
# Guess: attic, Clue: YYY--, Strategy: Exploitation, Attempt: 3
# Guess: agast, Clue: Y-G-Y, Strategy: Exploitation, Attempt: 4
# Guess: acing, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: coden, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is rache
# Guess: temse, Clue: -Y--G, Strategy: Exploitation, Attempt: 1
# Guess: alkos, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: coder, Clue: Y--YY, Strategy: Exploitation, Attempt: 3
# Guess: ainee, Clue: Y--YG, Strategy: Exploitation, Attempt: 4
# Guess: adobo, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: codex, Clue: Y--Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is kotow
# Guess: temse, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: codon, Clue: -G-G-, Strategy: Exploitation, Attempt: 2
# Guess: aceta, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: stend, Clue: -Y---, Strategy: Exploration, Attempt: 4
# Guess: bunns, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: tends, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is yeuky
# Guess: tenia, Clue: -G---, Strategy: Exploitation, Attempt: 1
# Guess: bafts, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: tenty, Clue: -G--G, Strategy: Exploitation, Attempt: 3
# Guess: agars, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: teres, Clue: -G-Y-, Strategy: Exploitation, Attempt: 5
# Guess: agama, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ovary
# Guess: terga, Clue: --Y-Y, Strategy: Exploitation, Attempt: 1
# Guess: aport, Clue: Y-YG-, Strategy: Exploitation, Attempt: 2
# Guess: acids, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: coeds, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: bunny, Clue: ----G, Strategy: Exploitation, Attempt: 5
# Guess: cabre, Clue: -Y-G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is seans
# Guess: terms, Clue: -G--G, Strategy: Exploitation, Attempt: 1
# Guess: agast, Clue: Y-GY-, Strategy: Exploitation, Attempt: 2
# Guess: absit, Clue: Y-Y--, Strategy: Exploitation, Attempt: 3
# Guess: axels, Clue: Y-Y-G, Strategy: Exploitation, Attempt: 4
# Guess: afear, Clue: Y-YY-, Strategy: Exploitation, Attempt: 5
# Guess: alant, Clue: Y-GG-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is hogan
# Guess: terne, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: cnida, Clue: -Y--Y, Strategy: Exploitation, Attempt: 2
# Guess: apery, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: coffs, Clue: -G---, Strategy: Exploitation, Attempt: 4
# Guess: bagel, Clue: -YG--, Strategy: Exploitation, Attempt: 5
# Guess: admin, Clue: Y---G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is corer
# Guess: terts, Clue: -YG--, Strategy: Exploitation, Attempt: 1
# Guess: admit, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: tetra, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 3
# Guess: angst, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: their, Clue: --Y-G, Strategy: Exploitation, Attempt: 5
# Guess: alloy, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is toric
# Guess: ramin, Clue: Y--G-, Strategy: Exploration, Attempt: 1
# Guess: alcos, Clue: --YY-, Strategy: Exploitation, Attempt: 2
# Guess: arroz, Clue: -YGY-, Strategy: Exploitation, Attempt: 3
# Guess: aboon, Clue: --YY-, Strategy: Exploitation, Attempt: 4
# Guess: arroz, Clue: -YGY-, Strategy: Exploitation, Attempt: 5
# Guess: abord, Clue: --YY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is hosel
# Guess: thens, Clue: -YY-Y, Strategy: Exploitation, Attempt: 1
# Guess: adunc, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: thens, Clue: -YY-Y, Strategy: Exploitation, Attempt: 3
# Guess: adust, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: coach, Clue: -G--Y, Strategy: Exploitation, Attempt: 5
# Guess: aglee, Clue: --YGY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is agora
# Guess: thens, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: thesp, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: thigh, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: coact, Clue: -YY--, Strategy: Exploitation, Attempt: 4
# Guess: antas, Clue: G--Y-, Strategy: Exploitation, Attempt: 5
# Guess: afald, Clue: G-Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is odder
# Guess: tians, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: ticed, Clue: ---GY, Strategy: Exploitation, Attempt: 2
# Guess: agood, Clue: --YYY, Strategy: Exploitation, Attempt: 3
# Guess: aggie, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: clews, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: cabal, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is lumen
# Guess: tiges, Clue: ---G-, Strategy: Exploitation, Attempt: 1
# Guess: bachs, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: livre, Clue: G---Y, Strategy: Exploration, Attempt: 3
# Guess: aecia, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: bunts, Clue: -GY--, Strategy: Exploitation, Attempt: 5
# Guess: afoot, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is quirk
# Guess: tight, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: bunty, Clue: -G---, Strategy: Exploitation, Attempt: 2
# Guess: baggy, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: tiler, Clue: -Y--Y, Strategy: Exploitation, Attempt: 4
# Guess: apgar, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: click, Clue: --G-G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is gunks
# Guess: tiles, Clue: ----G, Strategy: Exploitation, Attempt: 1
# Guess: cacao, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: tills, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: cacas, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: cache, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: timed, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is envoy
# Guess: tinas, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: cabas, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: tinea, Clue: --YY-, Strategy: Exploitation, Attempt: 3
# Guess: arroz, Clue: ---G-, Strategy: Exploitation, Attempt: 4
# Guess: backs, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: unlit, Clue: -G---, Strategy: Exploration, Attempt: 6
# The answer for this episode is crook
# Guess: night, Clue: -----, Strategy: Exploration, Attempt: 1
# Guess: tings, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: titup, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: toles, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: bunya, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: tolts, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is sully
# Guess: toman, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: tonal, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: clied, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: buoys, Clue: -G-YY, Strategy: Exploitation, Attempt: 4
# Guess: pelma, Clue: --G--, Strategy: Exploration, Attempt: 5
# Guess: argue, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is funny
# Guess: tonic, Clue: --G--, Strategy: Exploitation, Attempt: 1
# Guess: argus, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: coady, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: cacks, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: toper, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: torah, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is heald
# Guess: toran, Clue: ---Y-, Strategy: Exploitation, Attempt: 1
# Guess: coala, Clue: --GGY, Strategy: Exploitation, Attempt: 2
# Guess: aband, Clue: Y-G-G, Strategy: Exploitation, Attempt: 3
# Guess: abray, Clue: Y--Y-, Strategy: Exploitation, Attempt: 4
# Guess: ayont, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: cogie, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is cleep
# Guess: fluyt, Clue: -G---, Strategy: Exploration, Attempt: 1
# Guess: baghs, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: torcs, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: coala, Clue: G--Y-, Strategy: Exploitation, Attempt: 4
# Guess: afara, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: tores, Clue: ---G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is blook
# Guess: toric, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: buoys, Clue: G-G--, Strategy: Exploitation, Attempt: 2
# Guess: abers, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: buppy, Clue: G----, Strategy: Exploitation, Attempt: 4
# Guess: kuias, Clue: Y----, Strategy: Exploration, Attempt: 5
# Guess: cogon, Clue: -Y-G-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is stank
# Guess: tosas, Clue: Y-YYY, Strategy: Exploitation, Attempt: 1
# Guess: acnes, Clue: Y-Y-Y, Strategy: Exploitation, Attempt: 2
# Guess: amble, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: cogue, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: tosas, Clue: Y-YYY, Strategy: Exploitation, Attempt: 5
# Guess: acock, Clue: Y---G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is femur
# Guess: tosas, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: touts, Clue: --Y--, Strategy: Exploitation, Attempt: 2
# Guess: cabby, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: touze, Clue: --Y-Y, Strategy: Exploitation, Attempt: 4
# Guess: aport, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: coals, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is guffs
# Guess: banda, Clue: -----, Strategy: Exploration, Attempt: 1
# Guess: towel, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: towie, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: towns, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: cacky, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: towny, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is igloo
# Guess: tonga, Clue: -Y-Y-, Strategy: Exploration, Attempt: 1
# Guess: anigh, Clue: --YY-, Strategy: Exploitation, Attempt: 2
# Guess: arsed, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: trape, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: triff, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: caber, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is karri
# Guess: triol, Clue: -YY--, Strategy: Exploitation, Attempt: 1
# Guess: anted, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: cohab, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: coaly, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: cabin, Clue: -G-Y-, Strategy: Exploitation, Attempt: 5
# Guess: agami, Clue: Y-Y-G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is fills
# Guess: trios, Clue: --Y-G, Strategy: Exploitation, Attempt: 1
# Guess: allyl, Clue: -YG-Y, Strategy: Exploitation, Attempt: 2
# Guess: aboma, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: trois, Clue: ---YG, Strategy: Exploitation, Attempt: 4
# Guess: lured, Clue: Y----, Strategy: Exploration, Attempt: 5
# Guess: cohen, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is meare
# Guess: tryke, Clue: -Y--G, Strategy: Exploitation, Attempt: 1
# Guess: alkyd, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: cohoe, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: cacti, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: buran, Clue: --YY-, Strategy: Exploitation, Attempt: 5
# Guess: bonus, Clue: -----, Strategy: Exploration, Attempt: 6
# The answer for this episode is cisco
# Guess: tryma, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: tsars, Clue: -Y--Y, Strategy: Exploitation, Attempt: 2
# Guess: aphid, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: coapt, Clue: GY---, Strategy: Exploitation, Attempt: 4
# Guess: adder, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: cinqs, Clue: GG--Y, Strategy: Exploration, Attempt: 6
# The answer for this episode is bones
# Guess: blite, Clue: G---Y, Strategy: Exploration, Attempt: 1
# Guess: aedes, Clue: -Y-GG, Strategy: Exploitation, Attempt: 2
# Guess: aboil, Clue: -YY--, Strategy: Exploitation, Attempt: 3
# Guess: antes, Clue: -Y-GG, Strategy: Exploitation, Attempt: 4
# Guess: aboma, Clue: -YY--, Strategy: Exploitation, Attempt: 5
# Guess: antes, Clue: -Y-GG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is fight
# Guess: cinqs, Clue: -G---, Strategy: Exploitation, Attempt: 1
# Guess: bagie, Clue: --GY-, Strategy: Exploitation, Attempt: 2
# Guess: aedes, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: duals, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: tuffe, Clue: Y-YY-, Strategy: Exploitation, Attempt: 5
# Guess: powan, Clue: -----, Strategy: Exploration, Attempt: 6
# The answer for this episode is coney
# Guess: tuffe, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: prose, Clue: --Y-Y, Strategy: Exploration, Attempt: 2
# Guess: appal, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: tuina, Clue: ---Y-, Strategy: Exploitation, Attempt: 4
# Guess: coarb, Clue: GG---, Strategy: Exploitation, Attempt: 5
# Guess: acais, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is beigy
# Guess: tumor, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: tunds, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: tunny, Clue: ----G, Strategy: Exploitation, Attempt: 3
# Guess: caddy, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: cadee, Clue: ---YY, Strategy: Exploitation, Attempt: 5
# Guess: atuas, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is satis
# Guess: turps, Clue: Y---G, Strategy: Exploitation, Attempt: 1
# Guess: aloos, Clue: Y---G, Strategy: Exploitation, Attempt: 2
# ...
# Guess: doses, Clue: -Y-G-, Strategy: Exploitation, Attempt: 1
# Guess: aglow, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: cooly, Clue: YYY--, Strategy: Exploitation, Attempt: 3
# Guess: warms, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: carbo, Clue: Y-Y-Y, Strategy: Exploitation, Attempt: 5
# Guess: amici, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is plena
# Guess: feuds, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: foins, Clue: ---G-, Strategy: Exploration, Attempt: 2
# Guess: banns, Clue: -YYG-, Strategy: Exploitation, Attempt: 3
# Guess: aboon, Clue: Y---Y, Strategy: Exploitation, Attempt: 4
# Guess: asana, Clue: Y-YGG, Strategy: Exploitation, Attempt: 5
# Guess: abash, Clue: Y-Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is modem
# Guess: tacks, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: spets, Clue: --Y--, Strategy: Exploitation, Attempt: 2
# Guess: reist, Clue: -Y---, Strategy: Exploration, Attempt: 3
# Guess: camel, Clue: --YG-, Strategy: Exploitation, Attempt: 4
# Guess: aggro, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: comms, Clue: -GYY-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is abrin
# Guess: dames, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: cameo, Clue: -Y---, Strategy: Exploitation, Attempt: 2
# Guess: wheen, Clue: ----G, Strategy: Exploration, Attempt: 3
# Guess: carbo, Clue: -YGY-, Strategy: Exploitation, Attempt: 4
# Guess: abore, Clue: GG-Y-, Strategy: Exploitation, Attempt: 5
# Guess: abaya, Clue: GGY-Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is loury
# Guess: keirs, Clue: ---G-, Strategy: Exploitation, Attempt: 1
# Guess: banns, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: golps, Clue: -GY--, Strategy: Exploitation, Attempt: 3
# Guess: agars, Clue: ---G-, Strategy: Exploitation, Attempt: 4
# Guess: bants, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: linch, Clue: G----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is alary
# Guess: allis, Clue: GGY--, Strategy: Exploitation, Attempt: 1
# Guess: bocce, Clue: -----, Strategy: Exploration, Attempt: 2
# Guess: allis, Clue: GGY--, Strategy: Exploitation, Attempt: 3
# Guess: abaft, Clue: G-G--, Strategy: Exploitation, Attempt: 4
# Guess: abhor, Clue: G---Y, Strategy: Exploitation, Attempt: 5
# Guess: aesir, Clue: G---Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is bails
# Guess: allis, Clue: YYYYG, Strategy: Exploitation, Attempt: 1
# Guess: abaci, Clue: YYY-Y, Strategy: Exploitation, Attempt: 2
# Guess: abohm, Clue: YY---, Strategy: Exploitation, Attempt: 3
# Guess: anlas, Clue: Y-YYG, Strategy: Exploitation, Attempt: 4
# Guess: aboil, Clue: YY-YY, Strategy: Exploitation, Attempt: 5
# Guess: abies, Clue: YYG-G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is khans
# Guess: murks, Clue: ---YG, Strategy: Exploration, Attempt: 1
# Guess: amend, Clue: Y--G-, Strategy: Exploitation, Attempt: 2
# Guess: algal, Clue: Y--Y-, Strategy: Exploitation, Attempt: 3
# Guess: baels, Clue: -Y--G, Strategy: Exploitation, Attempt: 4
# Guess: allod, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: coths, Clue: ---YG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ranee
# Guess: allis, Clue: Y----, Strategy: Exploitation, Attempt: 1
# Guess: cotta, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: comms, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: allis, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: cotts, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: deros, Clue: -YY--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is chins
# Guess: posho, Clue: --YY-, Strategy: Exploration, Attempt: 1
# Guess: aspie, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 2
# Guess: anole, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: cames, Clue: G---G, Strategy: Exploitation, Attempt: 4
# Guess: canso, Clue: G-YY-, Strategy: Exploration, Attempt: 5
# Guess: abled, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is rubin
# Guess: aster, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: commy, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: krays, Clue: -Y---, Strategy: Exploitation, Attempt: 3
# Guess: camis, Clue: ---G-, Strategy: Exploitation, Attempt: 4
# Guess: bantu, Clue: Y-Y-Y, Strategy: Exploitation, Attempt: 5
# Guess: amide, Clue: --Y--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ditts
# Guess: walis, Clue: ---YG, Strategy: Exploitation, Attempt: 1
# Guess: amene, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: chose, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: coomb, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: spake, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: couch, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is tyros
# Guess: ensue, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: carbs, Clue: --G-G, Strategy: Exploitation, Attempt: 2
# Guess: adhan, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: exams, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: voles, Clue: -Y--G, Strategy: Exploration, Attempt: 5
# Guess: allot, Clue: ---GY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ohing
# Guess: pight, Clue: -YYY-, Strategy: Exploitation, Attempt: 1
# Guess: agars, Clue: -Y---, Strategy: Exploitation, Attempt: 2
# Guess: camos, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: jaffa, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: pight, Clue: -YYY-, Strategy: Exploitation, Attempt: 5
# Guess: agast, Clue: -Y---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is track
# Guess: pight, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: compo, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: coude, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: cough, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: could, Clue: Y----, Strategy: Exploitation, Attempt: 5
# Guess: count, Clue: Y---Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is nizam
# Guess: nudes, Clue: G----, Strategy: Exploitation, Attempt: 1
# Guess: arbor, Clue: Y----, Strategy: Exploitation, Attempt: 2
# Guess: coupe, Clue: -----, Strategy: Exploitation, Attempt: 3
# Guess: ylkes, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: degas, Clue: ---G-, Strategy: Exploitation, Attempt: 5
# Guess: banty, Clue: -YY--, Strategy: Exploitation, Attempt: 6
# The answer for this episode is games
# Guess: eales, Clue: YG-GG, Strategy: Exploitation, Attempt: 1
# Guess: aargh, Clue: YG-Y-, Strategy: Exploitation, Attempt: 2
# Guess: ablow, Clue: Y----, Strategy: Exploitation, Attempt: 3
# Guess: coups, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: carbo, Clue: -G---, Strategy: Exploitation, Attempt: 5
# Guess: bants, Clue: -G--G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is zonda
# Guess: moles, Clue: -G---, Strategy: Exploration, Attempt: 1
# Guess: bantu, Clue: -YG--, Strategy: Exploitation, Attempt: 2
# Guess: arras, Clue: Y--Y-, Strategy: Exploration, Attempt: 3
# Guess: baffs, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: campi, Clue: -Y---, Strategy: Exploitation, Attempt: 5
# Guess: campo, Clue: -Y--Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is gusle
# Guess: eales, Clue: Y-YYY, Strategy: Exploitation, Attempt: 1
# Guess: acros, Clue: ----Y, Strategy: Exploitation, Attempt: 2
# Guess: comps, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: compt, Clue: -----, Strategy: Exploitation, Attempt: 4
# Guess: eales, Clue: Y-YYY, Strategy: Exploitation, Attempt: 5
# Guess: acted, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is retry
# Guess: eales, Clue: Y--Y-, Strategy: Exploitation, Attempt: 1
# Guess: baffy, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: carbs, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: carby, Clue: --Y-G, Strategy: Exploitation, Attempt: 4
# Guess: alpha, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: eales, Clue: Y--Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is yells
# Guess: eales, Clue: Y-GYG, Strategy: Exploitation, Attempt: 1
# Guess: abase, Clue: ---YY, Strategy: Exploitation, Attempt: 2
# Guess: avize, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: brunt, Clue: -----, Strategy: Exploration, Attempt: 4
# Guess: eales, Clue: Y-GYG, Strategy: Exploitation, Attempt: 5
# Guess: abash, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is wears
# Guess: eales, Clue: YY-YG, Strategy: Exploitation, Attempt: 1
# Guess: abamp, Clue: Y-G--, Strategy: Exploitation, Attempt: 2
# Guess: agria, Clue: Y-Y-Y, Strategy: Exploitation, Attempt: 3
# Guess: amido, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: coven, Clue: ---Y-, Strategy: Exploration, Attempt: 5
# Guess: cooms, Clue: ----G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is troke
# Guess: eales, Clue: Y--Y-, Strategy: Exploitation, Attempt: 1
# Guess: bafts, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: coomy, Clue: -YG--, Strategy: Exploitation, Attempt: 3
# Guess: vairy, Clue: ---Y-, Strategy: Exploration, Attempt: 4
# Guess: coons, Clue: -YG--, Strategy: Exploitation, Attempt: 5
# Guess: adsum, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is ekkas
# Guess: eales, Clue: GY-YG, Strategy: Exploitation, Attempt: 1
# Guess: aarti, Clue: YY---, Strategy: Exploitation, Attempt: 2
# Guess: anlas, Clue: Y--GG, Strategy: Exploitation, Attempt: 3
# Guess: acini, Clue: Y----, Strategy: Exploitation, Attempt: 4
# Guess: courb, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: matey, Clue: -Y-Y-, Strategy: Exploration, Attempt: 6
# The answer for this episode is sprug
# Guess: eales, Clue: ----Y, Strategy: Exploitation, Attempt: 1
# Guess: comte, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: eales, Clue: ----Y, Strategy: Exploitation, Attempt: 3
# Guess: comus, Clue: ---GY, Strategy: Exploitation, Attempt: 4
# Guess: ahead, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: bindi, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is nabis
# Guess: emerg, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: nutsy, Clue: G--Y-, Strategy: Exploitation, Attempt: 2
# Guess: agars, Clue: Y-Y-G, Strategy: Exploitation, Attempt: 3
# Guess: afrit, Clue: Y--G-, Strategy: Exploitation, Attempt: 4
# Guess: algas, Clue: Y--YG, Strategy: Exploitation, Attempt: 5
# Guess: adred, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is nooit
# Guess: skyey, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: dally, Clue: -----, Strategy: Exploration, Attempt: 2
# Guess: tirrs, Clue: YY---, Strategy: Exploration, Attempt: 3
# Guess: anlas, Clue: -Y---, Strategy: Exploitation, Attempt: 4
# Guess: camps, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: britt, Clue: --YYG, Strategy: Exploitation, Attempt: 6
# The answer for this episode is piled
# Guess: britt, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: cardi, Clue: ---YY, Strategy: Exploitation, Attempt: 2
# Guess: avoid, Clue: ---YG, Strategy: Exploitation, Attempt: 3
# Guess: amens, Clue: --Y--, Strategy: Exploitation, Attempt: 4
# Guess: cards, Clue: ---Y-, Strategy: Exploitation, Attempt: 5
# Guess: coops, Clue: ---Y-, Strategy: Exploitation, Attempt: 6
# The answer for this episode is droke
# Guess: jetty, Clue: -Y---, Strategy: Exploitation, Attempt: 1
# Guess: campy, Clue: -----, Strategy: Exploitation, Attempt: 2
# Guess: aulos, Clue: ---Y-, Strategy: Exploitation, Attempt: 3
# Guess: coopt, Clue: -YG--, Strategy: Exploitation, Attempt: 4
# Guess: aduki, Clue: -Y-G-, Strategy: Exploitation, Attempt: 5
# Guess: aglus, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is mazey
# Guess: daals, Clue: -GY--, Strategy: Exploitation, Attempt: 1
# Guess: agast, Clue: Y-Y--, Strategy: Exploitation, Attempt: 2
# Guess: babas, Clue: -G-Y-, Strategy: Exploitation, Attempt: 3
# Guess: aggie, Clue: Y---Y, Strategy: Exploitation, Attempt: 4
# Guess: asana, Clue: Y-Y-Y, Strategy: Exploitation, Attempt: 5
# Guess: amids, Clue: YY---, Strategy: Exploitation, Attempt: 6
# The answer for this episode is pored
# Guess: geode, Clue: -YYYY, Strategy: Exploitation, Attempt: 1
# Guess: abram, Clue: --G--, Strategy: Exploitation, Attempt: 2
# Guess: arose, Clue: -YY-Y, Strategy: Exploitation, Attempt: 3
# Guess: afald, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: carby, Clue: --G--, Strategy: Exploitation, Attempt: 5
# Guess: arose, Clue: -YY-Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is truss
# Guess: geode, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: notum, Clue: --YY-, Strategy: Exploitation, Attempt: 2
# Guess: aspis, Clue: -Y--G, Strategy: Exploitation, Attempt: 3
# Guess: shtum, Clue: Y-YY-, Strategy: Exploration, Attempt: 4
# Guess: aldol, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: pechs, Clue: ----G, Strategy: Exploitation, Attempt: 6
# The answer for this episode is taler
# Guess: refit, Clue: YY--Y, Strategy: Exploitation, Attempt: 1
# Guess: adieu, Clue: Y--G-, Strategy: Exploitation, Attempt: 2
# Guess: algas, Clue: YY-Y-, Strategy: Exploitation, Attempt: 3
# Guess: venal, Clue: -Y-YY, Strategy: Exploration, Attempt: 4
# Guess: adorn, Clue: Y--Y-, Strategy: Exploitation, Attempt: 5
# Guess: bagel, Clue: -G-GY, Strategy: Exploitation, Attempt: 6
# The answer for this episode is fuels
# Guess: plant, Clue: -Y---, Strategy: Exploration, Attempt: 1
# Guess: camus, Clue: ---YG, Strategy: Exploitation, Attempt: 2
# Guess: ament, Clue: --G--, Strategy: Exploitation, Attempt: 3
# Guess: arpas, Clue: ----G, Strategy: Exploitation, Attempt: 4
# Guess: sneap, Clue: Y-G--, Strategy: Exploration, Attempt: 5
# Guess: agrin, Clue: -----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is coofs
# Guess: refit, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: cardy, Clue: G----, Strategy: Exploitation, Attempt: 2
# Guess: arced, Clue: --Y--, Strategy: Exploitation, Attempt: 3
# Guess: cared, Clue: G----, Strategy: Exploitation, Attempt: 4
# Guess: archi, Clue: --Y--, Strategy: Exploitation, Attempt: 5
# Guess: carer, Clue: G----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is herby
# Guess: arses, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 1
# Guess: anomy, Clue: ----G, Strategy: Exploitation, Attempt: 2
# Guess: cardi, Clue: --G--, Strategy: Exploitation, Attempt: 3
# Guess: arpen, Clue: -Y-Y-, Strategy: Exploitation, Attempt: 4
# Guess: ansae, Clue: ----Y, Strategy: Exploitation, Attempt: 5
# Guess: conch, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is taata
# Guess: yocks, Clue: -----, Strategy: Exploitation, Attempt: 1
# Guess: besaw, Clue: ---Y-, Strategy: Exploitation, Attempt: 2
# Guess: unlaw, Clue: ---Y-, Strategy: Exploration, Attempt: 3
# Guess: coost, Clue: ----Y, Strategy: Exploitation, Attempt: 4
# Guess: condo, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: azido, Clue: Y----, Strategy: Exploitation, Attempt: 6
# The answer for this episode is frere
# Guess: harms, Clue: --Y--, Strategy: Exploitation, Attempt: 1
# Guess: tofus, Clue: --Y--, Strategy: Exploration, Attempt: 2
# Guess: cares, Clue: --YY-, Strategy: Exploitation, Attempt: 3
# Guess: aspro, Clue: ---G-, Strategy: Exploitation, Attempt: 4
# Guess: banya, Clue: -----, Strategy: Exploitation, Attempt: 5
# Guess: glaur, Clue: ----Y, Strategy: Exploitation, Attempt: 6
# The answer for this episode is mardy
# Guess: gorse, Clue: --G--, Strategy: Exploitation, Attempt: 1
# Guess: arrah, Clue: YYGY-, Strategy: Exploitation, Attempt: 2
# Guess: abaka, Clue: Y-Y-Y, Strategy: Exploitation, Attempt: 3
# Guess: amies, Clue: YY---, Strategy: Exploitation, Attempt: 4
# Guess: annal, Clue: Y--Y-, Strategy: Exploitation, Attempt: 5
# Guess: bagel, Clue: -G---, Strategy: Exploitation, Attempt: 6
# Training completed after 10000 episodes
# Correct guesses: 2, Wrong guesses: 9998
